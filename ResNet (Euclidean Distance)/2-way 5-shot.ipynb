# %% [markdown]
# # Multilingual Offline Forged  Signature Using Siamese Neural Network and Few-Shot Learning

# %% [markdown]
# Contrastive Loss

# %% [markdown]
# 2-ways 5-shot

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)

# %%
import numpy as np
import os
import cv2
import itertools
import random

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
import tensorflow as tf

from keras import backend as K
from keras.optimizers import Adam
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, GlobalAveragePooling2D, Subtract
from keras.models import Model, Sequential
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.applications import DenseNet121
from keras.applications import ResNet50V2

import matplotlib.pyplot as plt
import numpy as np
from skimage.metrics import structural_similarity as ssim

# %%
# Paths to Datasets
cedar_path = "/content/drive/MyDrive/Multilingual dataset/CEDAR"
bengali_path = "/content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali"
hindi_path = "/content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi"

# All the images will be converted to the same size
img_h, img_w = 120, 120

# Preprocessing Function
def preprocess_image(img_path):
    image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read image in grayscale
    if image is None or len(image) == 0 or image.shape[0] == 0 or image.shape[1] == 0:
        print(f"Error: Image {img_path} is empty or None or has invalid dimensions.")
        return None
    image = cv2.resize(image, (img_h, img_w))
    image = cv2.merge((image, image, image))  # Convert grayscale to RGB
    image = image.astype('float32') / 255.0  # Normalize pixel values
    return image

# Load Data Function
def load_data(path, forged_count, genuine_count):
    dir_list = next(os.walk(path))[1]
    orig_groups, forg_groups = [], []
    for directory in dir_list:
        images = os.listdir(os.path.join(path, directory))
        images.sort()
        images = [os.path.join(path, directory, x) for x in images]
        forg_groups.append(images[:forged_count])
        orig_groups.append(images[forged_count:forged_count + genuine_count])
    return orig_groups, forg_groups

# Number of shots (images) for each class
shots_per_class = 5

# Total Number of genuine and forged images per folder of CEDAR, Bengali, and Hindi datasets
cedar_forged_count = 24
cedar_genuine_count = 24
bengali_forged_count = 30
bengali_genuine_count = 24
hindi_forged_count = 30
hindi_genuine_count = 24

# Load data with specified counts
orig_cedar, forg_cedar = load_data(cedar_path, cedar_forged_count, cedar_genuine_count)
orig_bengali, forg_bengali = load_data(bengali_path, bengali_forged_count, bengali_genuine_count)
orig_hindi, forg_hindi = load_data(hindi_path, hindi_forged_count, hindi_genuine_count)

# Randomly choose K-shots from each folder
random.seed(42)  # For reproducibility
random_forg_cedar = [random.sample(forg, shots_per_class) for forg in forg_cedar]
random_orig_cedar = [random.sample(orig, shots_per_class) for orig in orig_cedar]
random_forg_bengali = [random.sample(forg, shots_per_class) for forg in forg_bengali]
random_orig_bengali = [random.sample(orig, shots_per_class) for orig in orig_bengali]
random_forg_hindi = [random.sample(forg, shots_per_class) for forg in forg_hindi]
random_orig_hindi = [random.sample(orig, shots_per_class) for orig in orig_hindi]

# Combine Data
orig_groups = random_orig_cedar + random_orig_bengali + random_orig_hindi
forg_groups = random_forg_cedar + random_forg_bengali + random_forg_hindi

# Split Data into Train, Validation, and Test Sets
orig_train, orig_val_test, forg_train, forg_val_test = train_test_split(orig_groups, forg_groups, test_size=0.2, random_state=42)
orig_val, orig_test, forg_val, forg_test = train_test_split(orig_val_test, forg_val_test, test_size=0.5, random_state=42)

# Generate Batch Function
def generate_batch(orig_groups, forg_groups, batch_size=32):
    while True:
        pairs = [np.zeros((batch_size, img_h, img_w, 3)) for _ in range(2)]
        targets = np.zeros((batch_size,))

        for i in range(batch_size):
            if i < batch_size // 2:
                # Genuine-Genuine pairs
                pair_idx = np.random.randint(len(orig_groups), size=2)
                pair = (np.random.choice(orig_groups[pair_idx[0]]), np.random.choice(orig_groups[pair_idx[1]]))
                targets[i] = 1
            else:
                # Genuine-Forged pairs
                orig_idx = np.random.randint(len(orig_groups))
                orig = np.random.choice(orig_groups[orig_idx])
                forg = np.random.choice(forg_groups[orig_idx])
                pair = (orig, forg)
                targets[i] = 0

            img1 = preprocess_image(pair[0])
            img2 = preprocess_image(pair[1])

            pairs[0][i, :, :, :] = img1
            pairs[1][i, :, :, :] = img2

        yield pairs, targets

# Define batch size and generators
batch_size = 32
train_batch_generator = generate_batch(orig_train, forg_train, batch_size=batch_size)
val_batch_generator = generate_batch(orig_val_test, forg_val_test, batch_size=batch_size)
test_batch_generator = generate_batch(orig_test, forg_test, batch_size=batch_size)

# Define Contrastive Loss Function
# def contrastive_loss(y_true, y_pred):
#     margin = 1
#     square_pred = K.square(y_pred)
#     margin_square = K.square(K.maximum(margin - y_pred, 0))
#     return K.mean(y_true * square_pred + (1 - y_true) * margin_square)

# Define Siamese network model with ResNetV2 base
def get_siamese_model(input_shape):
    input_a = Input(shape=input_shape)
    input_b = Input(shape=input_shape)
    resnet_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=input_shape)
    resnet_model = Sequential([
        resnet_model,
        GlobalAveragePooling2D()
    ])
    processed_a = resnet_model(input_a)
    processed_b = resnet_model(input_b)
    distance = Lambda(lambda x: K.sqrt(K.sum(K.square(x[0] - x[1]), axis=-1, keepdims=True)))([processed_a, processed_b])
    output = Dense(1, activation='sigmoid')(distance)
    model = Model(inputs=[input_a, input_b], outputs=output)
    return model

# Compile Model with Contrastive Loss using Adam optimizer
input_shape = (img_h, img_w, 3)
model = get_siamese_model(input_shape)
# model.compile(loss=contrastive_loss, optimizer=Adam())
model.compile(loss="binary_crossentropy", optimizer=Adam(), metrics=["accuracy"])

# Define Callbacks
callbacks = [
    EarlyStopping(patience=4, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint('/content/drive/MyDrive/Multilingual dataset/Weights/2-ways 5-shots/ResNet Weight/resnet5shots-{epoch:03d}.h5',
                    verbose=1, save_best_only=True, save_weights_only=True)
]

# Train Model
num_train_samples = sum(len(group) for group in orig_train + forg_train)
num_val_samples = sum(len(group) for group in orig_val_test + forg_val_test)
steps_per_epoch_train = max(1, num_train_samples // batch_size)
steps_per_epoch_val = max(1, num_val_samples // batch_size)

results = model.fit(
    train_batch_generator,
    steps_per_epoch=steps_per_epoch_train,
    epochs=5,
    validation_data=val_batch_generator,
    validation_steps=steps_per_epoch_val,
    callbacks=callbacks
)
# Out:
# Epoch 1/5
# 78/78 [==============================] - ETA: 0s - loss: 0.7234 - accuracy: 0.5004
# Epoch 1: val_loss improved from inf to 4.46023, saving model to /content/drive/MyDrive/Multilingual dataset/Weights/2-ways 5-shots/ResNet Weight/resnet5shots-001.h5
# 78/78 [==============================] - 95s 666ms/step - loss: 0.7234 - accuracy: 0.5004 - val_loss: 4.4602 - val_accuracy: 0.5033 - lr: 0.0010
# Epoch 2/5
# 78/78 [==============================] - ETA: 0s - loss: 0.6423 - accuracy: 0.5561
# Epoch 2: val_loss improved from 4.46023 to 0.72679, saving model to /content/drive/MyDrive/Multilingual dataset/Weights/2-ways 5-shots/ResNet Weight/resnet5shots-002.h5
# 78/78 [==============================] - 48s 616ms/step - loss: 0.6423 - accuracy: 0.5561 - val_loss: 0.7268 - val_accuracy: 0.5033 - lr: 0.0010
# Epoch 3/5
# 78/78 [==============================] - ETA: 0s - loss: 0.6590 - accuracy: 0.5777
# Epoch 3: val_loss did not improve from 0.72679
# 78/78 [==============================] - 51s 661ms/step - loss: 0.6590 - accuracy: 0.5777 - val_loss: 0.8232 - val_accuracy: 0.4211 - lr: 0.0010
# Epoch 4/5
# 78/78 [==============================] - ETA: 0s - loss: 0.6254 - accuracy: 0.6342
# Epoch 4: val_loss did not improve from 0.72679
# 78/78 [==============================] - 48s 620ms/step - loss: 0.6254 - accuracy: 0.6342 - val_loss: 1.4644 - val_accuracy: 0.5049 - lr: 0.0010
# Epoch 5/5
# 78/78 [==============================] - ETA: 0s - loss: 0.5839 - accuracy: 0.7308
# Epoch 5: val_loss did not improve from 0.72679
# 78/78 [==============================] - 47s 606ms/step - loss: 0.5839 - accuracy: 0.7308 - val_loss: 0.9394 - val_accuracy: 0.5493 - lr: 0.0010

# %%
# Summary of the model
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 120, 120, 3)]        0         []
#
#  input_5 (InputLayer)        [(None, 120, 120, 3)]        0         []
#
#  sequential_1 (Sequential)   (None, 2048)                 2356480   ['input_4[0][0]',
#                                                           0          'input_5[0][0]']
#
#  lambda_1 (Lambda)           (None, 1)                    0         ['sequential_1[0][0]',
#                                                                      'sequential_1[1][0]']
#
#  dense_1 (Dense)             (None, 1)                    2         ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 23564802 (89.89 MB)
# Trainable params: 23519362 (89.72 MB)
# Non-trainable params: 45440 (177.50 KB)
# __________________________________________________________________________________________________

# %%
# Load best weights
model.load_weights('/content/drive/MyDrive/Multilingual dataset/Weights/2-ways 5-shots/ResNet Weight/resnet5shots-002.h5')

# %%
# Example: Predict on test data (replace with actual test data)
test_batch_inputs, test_batch_labels = next(test_batch_generator)
predictions = model.predict(test_batch_inputs)

# Function to compute ROC curve
def compute_roc_curve(predictions, labels):
    fpr, tpr, thresholds = roc_curve(labels, predictions)
    roc_auc = auc(fpr, tpr)
    return fpr, tpr, thresholds, roc_auc

# Compute ROC curve
fpr, tpr, thresholds, roc_auc = compute_roc_curve(predictions, test_batch_labels)

# Find the optimal threshold using Youden's J statistic
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]

# Apply the optimal threshold to predictions
predictions_binary = (predictions > optimal_threshold).astype(int) 

# Calculate metrics using the optimal threshold
accuracy = accuracy_score(test_batch_labels, predictions_binary)
precision = precision_score(test_batch_labels, predictions_binary)
recall = recall_score(test_batch_labels, predictions_binary)
f1 = f1_score(test_batch_labels, predictions_binary)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
print("Optimal Threshold:", optimal_threshold)
print("ROC AUC:", roc_auc)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# Accuracy: 0.65625
# Precision: 0.6086956521739131
# Recall: 0.875
# F1-Score: 0.717948717948718
# Optimal Threshold: 0.39514047
# ROC AUC: 0.61328125

# %%
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(test_batch_labels, predictions)

# Compute ROC AUC
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
def display_genuine_forged_with_ssim(model, test_batch_generator, num_pairs=16):
    test_batch_inputs, test_batch_labels = next(test_batch_generator)
    predictions = model.predict(test_batch_inputs)

    fig, axes = plt.subplots(num_pairs, 2, figsize=(8, 2*num_pairs))
    genuine_forged_pairs = [(test_batch_inputs[0][i], test_batch_inputs[1][i], test_batch_labels[i]) for i in range(len(test_batch_labels)) if test_batch_labels[i] == 0]

    ssim_scores = []
    for i in range(num_pairs):
        img1, img2, label = genuine_forged_pairs[i]
        ssim_score = ssim(img1, img2, multichannel=True)
        ssim_scores.append(ssim_score)

        axes[i, 0].imshow(img1)
        axes[i, 0].set_title(f"Image 1")
        axes[i, 0].axis('off')

        axes[i, 1].imshow(img2)
        axes[i, 1].set_title(f"Image 2 (SSIM: {ssim_score:.4f})")
        axes[i, 1].axis('off')

    plt.tight_layout()
    plt.show()

    # Calculate average SSIM score
    average_ssim = np.mean(ssim_scores)
    print("Average SSIM score:", average_ssim)

# Call the function to display genuine-forged image pairs with SSIM scores and print the average SSIM score
display_genuine_forged_with_ssim(model, test_batch_generator)
# Out:
# 1/1 [==============================] - 0s 34ms/step
# <ipython-input-43-f8cf05e75744>:11: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   ssim_score = ssim(img1, img2, multichannel=True)
# Average SSIM score: 0.7355843220506464

# %% [markdown]
# **Above Threshold:** If the similarity score is above the threshold, classify the pair as similar.
#
#
# **Below Threshold:** If the similarity score is below the threshold, classify the pair as dissimilar.

# %%
def show_similarity_score(model, orig_groups, forg_groups, img_h, img_w):
    # Select a random genuine image
    orig_idx = np.random.randint(len(orig_groups))
    orig = np.random.choice(orig_groups[orig_idx])

    # Select a random image (either genuine or forged)
    if np.random.randint(2) == 0:
        # Select a genuine image
        forg = np.random.choice(orig_groups[orig_idx])
        label = 1  # Set label to 1 for genuine pair
    else:
        # Select a forged image
        forg = np.random.choice(forg_groups[orig_idx])
        label = 0  # Set label to 0 for forged pair

    # Preprocess the images
    img1 = preprocess_image(orig)
    img2 = preprocess_image(forg)

    # Reshape the images for model input
    img1 = img1.reshape(1, img_h, img_w, 3)
    img2 = img2.reshape(1, img_h, img_w, 3)

    # Compute similarity score
    similarity_score = model.predict([img1, img2])[0][0]

    # Determine similarity or dissimilarity based on threshold
    threshold = optimal_threshold  # Adjust as needed
    if similarity_score >= threshold:
        similarity = "Similar"
    else:
        similarity = "Dissimilar"

    # Display the pair of images along with their similarity score
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(img1.squeeze())
    plt.title('Genuine Image')
    plt.subplot(1, 2, 2)
    plt.imshow(img2.squeeze())
    plt.title('Second Image')
    plt.suptitle('Similarity Score: {:.2f} ({})'.format(similarity_score, similarity))
    plt.show()

# Example usage
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 38ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 53ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 39ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 42ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 39ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 42ms/step

# %%
show_similarity_score(model, orig_groups, forg_groups, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 39ms/step

# %%
# Convert predictions to binary values (0 or 1) using optimal_threshold
binary_predictions = np.where(predictions >= optimal_threshold, 1, 0)
# Define colors for correct and incorrect predictions
colors = ['orange' if pred == label else 'red' for pred, label in zip(binary_predictions, test_batch_labels)]
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(range(len(predictions)), predictions.flatten(), color=colors)
plt.ylabel('Predicted Probability')
plt.title('Predicted Probabilities vs. Ground Truth Labels')
plt.xticks(range(len(predictions)))
plt.axhline(y=optimal_threshold, color='black', linestyle='--', linewidth=1)  # threshold line
# Add legend with correct and incorrect prediction labels
plt.legend(['Threshold', 'Correct Prediction', 'Incorrect Prediction'], loc='upper right')
plt.show()

# predictions, and labels
print("Predictions:")
print(predictions)
print("Ground Truth Labels:")
print(test_batch_labels)

# %%
# Predict on test data
predictions = model.predict(test_batch_generator, steps=len(orig_test))

# Extract distances from predictions
distances = predictions.flatten()

# Print distances between pairs of images
for i, distance in enumerate(distances):
    pair_type = "Genuine" if i < len(distances) // 2 else "Forged"
    print(f"Pair {i+1}: Type: {pair_type}, Distance: {distance:.4f}")
# Out:
# 32/32 [==============================] - 13s 432ms/step
# Pair 1: Type: Genuine, Distance: 0.4920
# Pair 2: Type: Genuine, Distance: 0.2649
# Pair 3: Type: Genuine, Distance: 0.2863
# Pair 4: Type: Genuine, Distance: 0.3035
# Pair 5: Type: Genuine, Distance: 0.3991
# Pair 6: Type: Genuine, Distance: 0.3337
# Pair 7: Type: Genuine, Distance: 0.3494
# Pair 8: Type: Genuine, Distance: 0.4739
# Pair 9: Type: Genuine, Distance: 0.5012
# Pair 10: Type: Genuine, Distance: 0.3900
# Pair 11: Type: Genuine, Distance: 0.3868
# Pair 12: Type: Genuine, Distance: 0.4468
# Pair 13: Type: Genuine, Distance: 0.3015
# Pair 14: Type: Genuine, Distance: 0.3493
# Pair 15: Type: Genuine, Distance: 0.4585
# Pair 16: Type: Genuine, Distance: 0.4590
# Pair 17: Type: Genuine, Distance: 0.3784
# Pair 18: Type: Genuine, Distance: 0.4815
# Pair 19: Type: Genuine, Distance: 0.4278
# Pair 20: Type: Genuine, Distance: 0.4927
# Pair 21: Type: Genuine, Distance: 0.4476
# Pair 22: Type: Genuine, Distance: 0.4318
# Pair 23: Type: Genuine, Distance: 0.3485
# Pair 24: Type: Genuine, Distance: 0.5083
# Pair 25: Type: Genuine, Distance: 0.3691
# Pair 26: Type: Genuine, Distance: 0.5082
# Pair 27: Type: Genuine, Distance: 0.4516
# Pair 28: Type: Genuine, Distance: 0.4941
# Pair 29: Type: Genuine, Distance: 0.4742
# Pair 30: Type: Genuine, Distance: 0.4074
# Pair 31: Type: Genuine, Distance: 0.4711
# Pair 32: Type: Genuine, Distance: 0.4475
# Pair 33: Type: Genuine, Distance: 0.4366
# Pair 34: Type: Genuine, Distance: 0.4424
# Pair 35: Type: Genuine, Distance: 0.4957
# Pair 36: Type: Genuine, Distance: 0.4524
# Pair 37: Type: Genuine, Distance: 0.3869
# Pair 38: Type: Genuine, Distance: 0.3786
# Pair 39: Type: Genuine, Distance: 0.4705
# Pair 40: Type: Genuine, Distance: 0.5260
# Pair 41: Type: Genuine, Distance: 0.3716
# Pair 42: Type: Genuine, Distance: 0.4755
# Pair 43: Type: Genuine, Distance: 0.5118
# Pair 44: Type: Genuine, Distance: 0.3676
# Pair 45: Type: Genuine, Distance: 0.3028
# Pair 46: Type: Genuine, Distance: 0.4691
# Pair 47: Type: Genuine, Distance: 0.3942
# Pair 48: Type: Genuine, Distance: 0.5081
# Pair 49: Type: Genuine, Distance: 0.4669
# Pair 50: Type: Genuine, Distance: 0.4487
# Pair 51: Type: Genuine, Distance: 0.4133
# Pair 52: Type: Genuine, Distance: 0.3497
# Pair 53: Type: Genuine, Distance: 0.4278
# Pair 54: Type: Genuine, Distance: 0.3797
# Pair 55: Type: Genuine, Distance: 0.1919
# Pair 56: Type: Genuine, Distance: 0.4609
# Pair 57: Type: Genuine, Distance: 0.4455
# Pair 58: Type: Genuine, Distance: 0.4456
# Pair 59: Type: Genuine, Distance: 0.4579
# Pair 60: Type: Genuine, Distance: 0.5056
# Pair 61: Type: Genuine, Distance: 0.4390
# Pair 62: Type: Genuine, Distance: 0.3653
# Pair 63: Type: Genuine, Distance: 0.4406
# Pair 64: Type: Genuine, Distance: 0.4885
# Pair 65: Type: Genuine, Distance: 0.4143
# Pair 66: Type: Genuine, Distance: 0.4521
# Pair 67: Type: Genuine, Distance: 0.3659
# Pair 68: Type: Genuine, Distance: 0.4746
# Pair 69: Type: Genuine, Distance: 0.3444
# Pair 70: Type: Genuine, Distance: 0.4596
# Pair 71: Type: Genuine, Distance: 0.4007
# Pair 72: Type: Genuine, Distance: 0.4647
# Pair 73: Type: Genuine, Distance: 0.4902
# Pair 74: Type: Genuine, Distance: 0.4835
# Pair 75: Type: Genuine, Distance: 0.4117
# Pair 76: Type: Genuine, Distance: 0.4538
# Pair 77: Type: Genuine, Distance: 0.4490
# Pair 78: Type: Genuine, Distance: 0.4824
# Pair 79: Type: Genuine, Distance: 0.4205
# Pair 80: Type: Genuine, Distance: 0.4188
# Pair 81: Type: Genuine, Distance: 0.4190
# Pair 82: Type: Genuine, Distance: 0.4406
# Pair 83: Type: Genuine, Distance: 0.4155
# Pair 84: Type: Genuine, Distance: 0.3982
# Pair 85: Type: Genuine, Distance: 0.4246
# Pair 86: Type: Genuine, Distance: 0.4496
# Pair 87: Type: Genuine, Distance: 0.4711
# Pair 88: Type: Genuine, Distance: 0.3884
# Pair 89: Type: Genuine, Distance: 0.4688
# Pair 90: Type: Genuine, Distance: 0.4441
# Pair 91: Type: Genuine, Distance: 0.4339
# Pair 92: Type: Genuine, Distance: 0.4542
# Pair 93: Type: Genuine, Distance: 0.5124
# Pair 94: Type: Genuine, Distance: 0.4801
# Pair 95: Type: Genuine, Distance: 0.4839
# Pair 96: Type: Genuine, Distance: 0.4456
# Pair 97: Type: Genuine, Distance: 0.3915
# Pair 98: Type: Genuine, Distance: 0.4693
# Pair 99: Type: Genuine, Distance: 0.4684
# Pair 100: Type: Genuine, Distance: 0.2902
# Pair 101: Type: Genuine, Distance: 0.3986
# Pair 102: Type: Genuine, Distance: 0.3844
# Pair 103: Type: Genuine, Distance: 0.3925
# Pair 104: Type: Genuine, Distance: 0.4936
# Pair 105: Type: Genuine, Distance: 0.4708
# Pair 106: Type: Genuine, Distance: 0.4731
# Pair 107: Type: Genuine, Distance: 0.4877
# Pair 108: Type: Genuine, Distance: 0.4793
# Pair 109: Type: Genuine, Distance: 0.4817
# Pair 110: Type: Genuine, Distance: 0.4915
# Pair 111: Type: Genuine, Distance: 0.4397
# Pair 112: Type: Genuine, Distance: 0.4760
# Pair 113: Type: Genuine, Distance: 0.4689
# Pair 114: Type: Genuine, Distance: 0.4632
# Pair 115: Type: Genuine, Distance: 0.4162
# Pair 116: Type: Genuine, Distance: 0.4451
# Pair 117: Type: Genuine, Distance: 0.4322
# Pair 118: Type: Genuine, Distance: 0.4831
# Pair 119: Type: Genuine, Distance: 0.5100
# Pair 120: Type: Genuine, Distance: 0.4543
# Pair 121: Type: Genuine, Distance: 0.3747
# Pair 122: Type: Genuine, Distance: 0.4656
# Pair 123: Type: Genuine, Distance: 0.3675
# Pair 124: Type: Genuine, Distance: 0.3283
# Pair 125: Type: Genuine, Distance: 0.3931
# Pair 126: Type: Genuine, Distance: 0.4859
# Pair 127: Type: Genuine, Distance: 0.4868
# Pair 128: Type: Genuine, Distance: 0.5123
# Pair 129: Type: Genuine, Distance: 0.3676
# Pair 130: Type: Genuine, Distance: 0.3671
# Pair 131: Type: Genuine, Distance: 0.4061
# Pair 132: Type: Genuine, Distance: 0.5260
# Pair 133: Type: Genuine, Distance: 0.3402
# Pair 134: Type: Genuine, Distance: 0.4569
# Pair 135: Type: Genuine, Distance: 0.4501
# Pair 136: Type: Genuine, Distance: 0.4054
# Pair 137: Type: Genuine, Distance: 0.4684
# Pair 138: Type: Genuine, Distance: 0.4668
# Pair 139: Type: Genuine, Distance: 0.3593
# Pair 140: Type: Genuine, Distance: 0.4204
# Pair 141: Type: Genuine, Distance: 0.5010
# Pair 142: Type: Genuine, Distance: 0.4770
# Pair 143: Type: Genuine, Distance: 0.4313
# Pair 144: Type: Genuine, Distance: 0.4520
# Pair 145: Type: Genuine, Distance: 0.4650
# Pair 146: Type: Genuine, Distance: 0.4545
# Pair 147: Type: Genuine, Distance: 0.4960
# Pair 148: Type: Genuine, Distance: 0.4478
# Pair 149: Type: Genuine, Distance: 0.4618
# Pair 150: Type: Genuine, Distance: 0.4816
# Pair 151: Type: Genuine, Distance: 0.4875
# Pair 152: Type: Genuine, Distance: 0.3034
# Pair 153: Type: Genuine, Distance: 0.5147
# Pair 154: Type: Genuine, Distance: 0.4589
# Pair 155: Type: Genuine, Distance: 0.5123
# Pair 156: Type: Genuine, Distance: 0.4900
# Pair 157: Type: Genuine, Distance: 0.4104
# Pair 158: Type: Genuine, Distance: 0.4417
# Pair 159: Type: Genuine, Distance: 0.4022
# Pair 160: Type: Genuine, Distance: 0.4734
# Pair 161: Type: Genuine, Distance: 0.4618
# Pair 162: Type: Genuine, Distance: 0.4436
# Pair 163: Type: Genuine, Distance: 0.5009
# Pair 164: Type: Genuine, Distance: 0.4635
# Pair 165: Type: Genuine, Distance: 0.4797
# Pair 166: Type: Genuine, Distance: 0.4190
# Pair 167: Type: Genuine, Distance: 0.4371
# Pair 168: Type: Genuine, Distance: 0.4372
# Pair 169: Type: Genuine, Distance: 0.4508
# Pair 170: Type: Genuine, Distance: 0.4404
# Pair 171: Type: Genuine, Distance: 0.3674
# Pair 172: Type: Genuine, Distance: 0.3613
# Pair 173: Type: Genuine, Distance: 0.4686
# Pair 174: Type: Genuine, Distance: 0.4905
# Pair 175: Type: Genuine, Distance: 0.4229
# Pair 176: Type: Genuine, Distance: 0.3576
# Pair 177: Type: Genuine, Distance: 0.4754
# Pair 178: Type: Genuine, Distance: 0.5046
# Pair 179: Type: Genuine, Distance: 0.1919
# Pair 180: Type: Genuine, Distance: 0.4361
# Pair 181: Type: Genuine, Distance: 0.4269
# Pair 182: Type: Genuine, Distance: 0.3856
# Pair 183: Type: Genuine, Distance: 0.4462
# Pair 184: Type: Genuine, Distance: 0.3665
# Pair 185: Type: Genuine, Distance: 0.3390
# Pair 186: Type: Genuine, Distance: 0.4677
# Pair 187: Type: Genuine, Distance: 0.4127
# Pair 188: Type: Genuine, Distance: 0.4621
# Pair 189: Type: Genuine, Distance: 0.4948
# Pair 190: Type: Genuine, Distance: 0.4086
# Pair 191: Type: Genuine, Distance: 0.3913
# Pair 192: Type: Genuine, Distance: 0.3485
# Pair 193: Type: Genuine, Distance: 0.4197
# Pair 194: Type: Genuine, Distance: 0.3936
# Pair 195: Type: Genuine, Distance: 0.4551
# Pair 196: Type: Genuine, Distance: 0.4794
# Pair 197: Type: Genuine, Distance: 0.4932
# Pair 198: Type: Genuine, Distance: 0.4693
# Pair 199: Type: Genuine, Distance: 0.3666
# Pair 200: Type: Genuine, Distance: 0.4954
# Pair 201: Type: Genuine, Distance: 0.4701
# Pair 202: Type: Genuine, Distance: 0.4981
# Pair 203: Type: Genuine, Distance: 0.4929
# Pair 204: Type: Genuine, Distance: 0.4538
# Pair 205: Type: Genuine, Distance: 0.4414
# Pair 206: Type: Genuine, Distance: 0.4731
# Pair 207: Type: Genuine, Distance: 0.5061
# Pair 208: Type: Genuine, Distance: 0.4874
# Pair 209: Type: Genuine, Distance: 0.4683
# Pair 210: Type: Genuine, Distance: 0.4999
# Pair 211: Type: Genuine, Distance: 0.4190
# Pair 212: Type: Genuine, Distance: 0.4816
# Pair 213: Type: Genuine, Distance: 0.4945
# Pair 214: Type: Genuine, Distance: 0.5077
# Pair 215: Type: Genuine, Distance: 0.3404
# Pair 216: Type: Genuine, Distance: 0.4954
# Pair 217: Type: Genuine, Distance: 0.4491
# Pair 218: Type: Genuine, Distance: 0.3734
# Pair 219: Type: Genuine, Distance: 0.5074
# Pair 220: Type: Genuine, Distance: 0.4525
# Pair 221: Type: Genuine, Distance: 0.4057
# Pair 222: Type: Genuine, Distance: 0.3885
# Pair 223: Type: Genuine, Distance: 0.4757
# Pair 224: Type: Genuine, Distance: 0.4921
# Pair 225: Type: Genuine, Distance: 0.4380
# Pair 226: Type: Genuine, Distance: 0.4733
# Pair 227: Type: Genuine, Distance: 0.4480
# Pair 228: Type: Genuine, Distance: 0.4354
# Pair 229: Type: Genuine, Distance: 0.3497
# Pair 230: Type: Genuine, Distance: 0.4448
# Pair 231: Type: Genuine, Distance: 0.3805
# Pair 232: Type: Genuine, Distance: 0.4055
# Pair 233: Type: Genuine, Distance: 0.4018
# Pair 234: Type: Genuine, Distance: 0.4780
# Pair 235: Type: Genuine, Distance: 0.4621
# Pair 236: Type: Genuine, Distance: 0.4948
# Pair 237: Type: Genuine, Distance: 0.4693
# Pair 238: Type: Genuine, Distance: 0.3949
# Pair 239: Type: Genuine, Distance: 0.4450
# Pair 240: Type: Genuine, Distance: 0.4779
# Pair 241: Type: Genuine, Distance: 0.4487
# Pair 242: Type: Genuine, Distance: 0.4875
# Pair 243: Type: Genuine, Distance: 0.4330
# Pair 244: Type: Genuine, Distance: 0.4643
# Pair 245: Type: Genuine, Distance: 0.4268
# Pair 246: Type: Genuine, Distance: 0.4929
# Pair 247: Type: Genuine, Distance: 0.3646
# Pair 248: Type: Genuine, Distance: 0.4380
# Pair 249: Type: Genuine, Distance: 0.4795
# Pair 250: Type: Genuine, Distance: 0.4913
# Pair 251: Type: Genuine, Distance: 0.4816
# Pair 252: Type: Genuine, Distance: 0.4778
# Pair 253: Type: Genuine, Distance: 0.4530
# Pair 254: Type: Genuine, Distance: 0.5030
# Pair 255: Type: Genuine, Distance: 0.4819
# Pair 256: Type: Genuine, Distance: 0.3672
# Pair 257: Type: Genuine, Distance: 0.4890
# Pair 258: Type: Genuine, Distance: 0.2558
# Pair 259: Type: Genuine, Distance: 0.4167
# Pair 260: Type: Genuine, Distance: 0.2553
# Pair 261: Type: Genuine, Distance: 0.4243
# Pair 262: Type: Genuine, Distance: 0.3480
# Pair 263: Type: Genuine, Distance: 0.4310
# Pair 264: Type: Genuine, Distance: 0.4816
# Pair 265: Type: Genuine, Distance: 0.4755
# Pair 266: Type: Genuine, Distance: 0.4204
# Pair 267: Type: Genuine, Distance: 0.4512
# Pair 268: Type: Genuine, Distance: 0.4213
# Pair 269: Type: Genuine, Distance: 0.3684
# Pair 270: Type: Genuine, Distance: 0.5048
# Pair 271: Type: Genuine, Distance: 0.4679
# Pair 272: Type: Genuine, Distance: 0.3912
# Pair 273: Type: Genuine, Distance: 0.4417
# Pair 274: Type: Genuine, Distance: 0.4869
# Pair 275: Type: Genuine, Distance: 0.4587
# Pair 276: Type: Genuine, Distance: 0.4588
# Pair 277: Type: Genuine, Distance: 0.4597
# Pair 278: Type: Genuine, Distance: 0.5193
# Pair 279: Type: Genuine, Distance: 0.3936
# Pair 280: Type: Genuine, Distance: 0.5140
# Pair 281: Type: Genuine, Distance: 0.4541
# Pair 282: Type: Genuine, Distance: 0.3966
# Pair 283: Type: Genuine, Distance: 0.4611
# Pair 284: Type: Genuine, Distance: 0.5005
# Pair 285: Type: Genuine, Distance: 0.4521
# Pair 286: Type: Genuine, Distance: 0.4372
# Pair 287: Type: Genuine, Distance: 0.4432
# Pair 288: Type: Genuine, Distance: 0.3921
# Pair 289: Type: Genuine, Distance: 0.5089
# Pair 290: Type: Genuine, Distance: 0.4343
# Pair 291: Type: Genuine, Distance: 0.2946
# Pair 292: Type: Genuine, Distance: 0.3066
# Pair 293: Type: Genuine, Distance: 0.3993
# Pair 294: Type: Genuine, Distance: 0.4028
# Pair 295: Type: Genuine, Distance: 0.4497
# Pair 296: Type: Genuine, Distance: 0.4508
# Pair 297: Type: Genuine, Distance: 0.3051
# Pair 298: Type: Genuine, Distance: 0.4254
# Pair 299: Type: Genuine, Distance: 0.2947
# Pair 300: Type: Genuine, Distance: 0.3775
# Pair 301: Type: Genuine, Distance: 0.5018
# Pair 302: Type: Genuine, Distance: 0.4892
# Pair 303: Type: Genuine, Distance: 0.3560
# Pair 304: Type: Genuine, Distance: 0.4999
# Pair 305: Type: Genuine, Distance: 0.4980
# Pair 306: Type: Genuine, Distance: 0.4927
# Pair 307: Type: Genuine, Distance: 0.4959
# Pair 308: Type: Genuine, Distance: 0.3485
# Pair 309: Type: Genuine, Distance: 0.4521
# Pair 310: Type: Genuine, Distance: 0.4884
# Pair 311: Type: Genuine, Distance: 0.3661
# Pair 312: Type: Genuine, Distance: 0.4587
# Pair 313: Type: Genuine, Distance: 0.4751
# Pair 314: Type: Genuine, Distance: 0.4999
# Pair 315: Type: Genuine, Distance: 0.3656
# Pair 316: Type: Genuine, Distance: 0.4425
# Pair 317: Type: Genuine, Distance: 0.4100
# Pair 318: Type: Genuine, Distance: 0.4429
# Pair 319: Type: Genuine, Distance: 0.3988
# Pair 320: Type: Genuine, Distance: 0.5012
# Pair 321: Type: Genuine, Distance: 0.5036
# Pair 322: Type: Genuine, Distance: 0.3575
# Pair 323: Type: Genuine, Distance: 0.4367
# Pair 324: Type: Genuine, Distance: 0.4960
# Pair 325: Type: Genuine, Distance: 0.4940
# Pair 326: Type: Genuine, Distance: 0.3705
# Pair 327: Type: Genuine, Distance: 0.3852
# Pair 328: Type: Genuine, Distance: 0.3762
# Pair 329: Type: Genuine, Distance: 0.4845
# Pair 330: Type: Genuine, Distance: 0.4620
# Pair 331: Type: Genuine, Distance: 0.3371
# Pair 332: Type: Genuine, Distance: 0.4194
# Pair 333: Type: Genuine, Distance: 0.3227
# Pair 334: Type: Genuine, Distance: 0.4827
# Pair 335: Type: Genuine, Distance: 0.3386
# Pair 336: Type: Genuine, Distance: 0.3995
# Pair 337: Type: Genuine, Distance: 0.3941
# Pair 338: Type: Genuine, Distance: 0.4417
# Pair 339: Type: Genuine, Distance: 0.4342
# Pair 340: Type: Genuine, Distance: 0.4024
# Pair 341: Type: Genuine, Distance: 0.5127
# Pair 342: Type: Genuine, Distance: 0.4981
# Pair 343: Type: Genuine, Distance: 0.4248
# Pair 344: Type: Genuine, Distance: 0.2136
# Pair 345: Type: Genuine, Distance: 0.4741
# Pair 346: Type: Genuine, Distance: 0.5113
# Pair 347: Type: Genuine, Distance: 0.3811
# Pair 348: Type: Genuine, Distance: 0.4240
# Pair 349: Type: Genuine, Distance: 0.4104
# Pair 350: Type: Genuine, Distance: 0.4159
# Pair 351: Type: Genuine, Distance: 0.4452
# Pair 352: Type: Genuine, Distance: 0.4608
# Pair 353: Type: Genuine, Distance: 0.3933
# Pair 354: Type: Genuine, Distance: 0.4855
# Pair 355: Type: Genuine, Distance: 0.3480
# Pair 356: Type: Genuine, Distance: 0.4680
# Pair 357: Type: Genuine, Distance: 0.4590
# Pair 358: Type: Genuine, Distance: 0.4884
# Pair 359: Type: Genuine, Distance: 0.4710
# Pair 360: Type: Genuine, Distance: 0.4780
# Pair 361: Type: Genuine, Distance: 0.4940
# Pair 362: Type: Genuine, Distance: 0.3773
# Pair 363: Type: Genuine, Distance: 0.4657
# Pair 364: Type: Genuine, Distance: 0.5057
# Pair 365: Type: Genuine, Distance: 0.3683
# Pair 366: Type: Genuine, Distance: 0.4555
# Pair 367: Type: Genuine, Distance: 0.4421
# Pair 368: Type: Genuine, Distance: 0.4682
# Pair 369: Type: Genuine, Distance: 0.4419
# Pair 370: Type: Genuine, Distance: 0.5147
# Pair 371: Type: Genuine, Distance: 0.4020
# Pair 372: Type: Genuine, Distance: 0.3811
# Pair 373: Type: Genuine, Distance: 0.4041
# Pair 374: Type: Genuine, Distance: 0.4669
# Pair 375: Type: Genuine, Distance: 0.4670
# Pair 376: Type: Genuine, Distance: 0.4325
# Pair 377: Type: Genuine, Distance: 0.4458
# Pair 378: Type: Genuine, Distance: 0.5042
# Pair 379: Type: Genuine, Distance: 0.4342
# Pair 380: Type: Genuine, Distance: 0.3750
# Pair 381: Type: Genuine, Distance: 0.4074
# Pair 382: Type: Genuine, Distance: 0.4506
# Pair 383: Type: Genuine, Distance: 0.5012
# Pair 384: Type: Genuine, Distance: 0.4630
# Pair 385: Type: Genuine, Distance: 0.4330
# Pair 386: Type: Genuine, Distance: 0.3508
# Pair 387: Type: Genuine, Distance: 0.4980
# Pair 388: Type: Genuine, Distance: 0.4287
# Pair 389: Type: Genuine, Distance: 0.4728
# Pair 390: Type: Genuine, Distance: 0.4833
# Pair 391: Type: Genuine, Distance: 0.4466
# Pair 392: Type: Genuine, Distance: 0.4987
# Pair 393: Type: Genuine, Distance: 0.4525
# Pair 394: Type: Genuine, Distance: 0.3645
# Pair 395: Type: Genuine, Distance: 0.4799
# Pair 396: Type: Genuine, Distance: 0.4141
# Pair 397: Type: Genuine, Distance: 0.5050
# Pair 398: Type: Genuine, Distance: 0.4615
# Pair 399: Type: Genuine, Distance: 0.5010
# Pair 400: Type: Genuine, Distance: 0.4478
# Pair 401: Type: Genuine, Distance: 0.4406
# Pair 402: Type: Genuine, Distance: 0.5037
# Pair 403: Type: Genuine, Distance: 0.4078
# Pair 404: Type: Genuine, Distance: 0.2739
# Pair 405: Type: Genuine, Distance: 0.3797
# Pair 406: Type: Genuine, Distance: 0.4917
# Pair 407: Type: Genuine, Distance: 0.4441
# Pair 408: Type: Genuine, Distance: 0.4431
# Pair 409: Type: Genuine, Distance: 0.4339
# Pair 410: Type: Genuine, Distance: 0.4913
# Pair 411: Type: Genuine, Distance: 0.4920
# Pair 412: Type: Genuine, Distance: 0.3769
# Pair 413: Type: Genuine, Distance: 0.4342
# Pair 414: Type: Genuine, Distance: 0.4740
# Pair 415: Type: Genuine, Distance: 0.3976
# Pair 416: Type: Genuine, Distance: 0.4852
# Pair 417: Type: Genuine, Distance: 0.4229
# Pair 418: Type: Genuine, Distance: 0.4781
# Pair 419: Type: Genuine, Distance: 0.4478
# Pair 420: Type: Genuine, Distance: 0.4306
# Pair 421: Type: Genuine, Distance: 0.4988
# Pair 422: Type: Genuine, Distance: 0.3178
# Pair 423: Type: Genuine, Distance: 0.3575
# Pair 424: Type: Genuine, Distance: 0.4512
# Pair 425: Type: Genuine, Distance: 0.5126
# Pair 426: Type: Genuine, Distance: 0.4895
# Pair 427: Type: Genuine, Distance: 0.3611
# Pair 428: Type: Genuine, Distance: 0.4257
# Pair 429: Type: Genuine, Distance: 0.4451
# Pair 430: Type: Genuine, Distance: 0.4176
# Pair 431: Type: Genuine, Distance: 0.2938
# Pair 432: Type: Genuine, Distance: 0.5038
# Pair 433: Type: Genuine, Distance: 0.4805
# Pair 434: Type: Genuine, Distance: 0.3899
# Pair 435: Type: Genuine, Distance: 0.4962
# Pair 436: Type: Genuine, Distance: 0.4285
# Pair 437: Type: Genuine, Distance: 0.4074
# Pair 438: Type: Genuine, Distance: 0.3932
# Pair 439: Type: Genuine, Distance: 0.4861
# Pair 440: Type: Genuine, Distance: 0.4385
# Pair 441: Type: Genuine, Distance: 0.4127
# Pair 442: Type: Genuine, Distance: 0.5073
# Pair 443: Type: Genuine, Distance: 0.4709
# Pair 444: Type: Genuine, Distance: 0.4922
# Pair 445: Type: Genuine, Distance: 0.4543
# Pair 446: Type: Genuine, Distance: 0.3989
# Pair 447: Type: Genuine, Distance: 0.5084
# Pair 448: Type: Genuine, Distance: 0.4864
# Pair 449: Type: Genuine, Distance: 0.4506
# Pair 450: Type: Genuine, Distance: 0.4436
# Pair 451: Type: Genuine, Distance: 0.4432
# Pair 452: Type: Genuine, Distance: 0.4908
# Pair 453: Type: Genuine, Distance: 0.4782
# Pair 454: Type: Genuine, Distance: 0.4917
# Pair 455: Type: Genuine, Distance: 0.4236
# Pair 456: Type: Genuine, Distance: 0.4357
# Pair 457: Type: Genuine, Distance: 0.4508
# Pair 458: Type: Genuine, Distance: 0.4315
# Pair 459: Type: Genuine, Distance: 0.3367
# Pair 460: Type: Genuine, Distance: 0.4381
# Pair 461: Type: Genuine, Distance: 0.4439
# Pair 462: Type: Genuine, Distance: 0.4735
# Pair 463: Type: Genuine, Distance: 0.4410
# Pair 464: Type: Genuine, Distance: 0.4575
# Pair 465: Type: Genuine, Distance: 0.3625
# Pair 466: Type: Genuine, Distance: 0.4963
# Pair 467: Type: Genuine, Distance: 0.3859
# Pair 468: Type: Genuine, Distance: 0.3265
# Pair 469: Type: Genuine, Distance: 0.4618
# Pair 470: Type: Genuine, Distance: 0.3419
# Pair 471: Type: Genuine, Distance: 0.4709
# Pair 472: Type: Genuine, Distance: 0.4491
# Pair 473: Type: Genuine, Distance: 0.3984
# Pair 474: Type: Genuine, Distance: 0.3896
# Pair 475: Type: Genuine, Distance: 0.4208
# Pair 476: Type: Genuine, Distance: 0.3944
# Pair 477: Type: Genuine, Distance: 0.4847
# Pair 478: Type: Genuine, Distance: 0.5008
# Pair 479: Type: Genuine, Distance: 0.4815
# Pair 480: Type: Genuine, Distance: 0.4985
# Pair 481: Type: Genuine, Distance: 0.4643
# Pair 482: Type: Genuine, Distance: 0.4916
# Pair 483: Type: Genuine, Distance: 0.4036
# Pair 484: Type: Genuine, Distance: 0.4748
# Pair 485: Type: Genuine, Distance: 0.5053
# Pair 486: Type: Genuine, Distance: 0.3888
# Pair 487: Type: Genuine, Distance: 0.5046
# Pair 488: Type: Genuine, Distance: 0.4483
# Pair 489: Type: Genuine, Distance: 0.4827
# Pair 490: Type: Genuine, Distance: 0.4615
# Pair 491: Type: Genuine, Distance: 0.5001
# Pair 492: Type: Genuine, Distance: 0.4584
# Pair 493: Type: Genuine, Distance: 0.4948
# Pair 494: Type: Genuine, Distance: 0.5005
# Pair 495: Type: Genuine, Distance: 0.4324
# Pair 496: Type: Genuine, Distance: 0.5010
# Pair 497: Type: Genuine, Distance: 0.4667
# Pair 498: Type: Genuine, Distance: 0.4854
# Pair 499: Type: Genuine, Distance: 0.4372
# Pair 500: Type: Genuine, Distance: 0.3913
# Pair 501: Type: Genuine, Distance: 0.3547
# Pair 502: Type: Genuine, Distance: 0.3540
# Pair 503: Type: Genuine, Distance: 0.4918
# Pair 504: Type: Genuine, Distance: 0.4963
# Pair 505: Type: Genuine, Distance: 0.4960
# Pair 506: Type: Genuine, Distance: 0.4409
# Pair 507: Type: Genuine, Distance: 0.4902
# Pair 508: Type: Genuine, Distance: 0.4491
# Pair 509: Type: Genuine, Distance: 0.5009
# Pair 510: Type: Genuine, Distance: 0.4929
# Pair 511: Type: Genuine, Distance: 0.4879
# Pair 512: Type: Genuine, Distance: 0.4387
# Pair 513: Type: Forged, Distance: 0.4721
# Pair 514: Type: Forged, Distance: 0.4018
# Pair 515: Type: Forged, Distance: 0.4456
# Pair 516: Type: Forged, Distance: 0.3729
# Pair 517: Type: Forged, Distance: 0.4862
# Pair 518: Type: Forged, Distance: 0.4655
# Pair 519: Type: Forged, Distance: 0.4242
# Pair 520: Type: Forged, Distance: 0.4536
# Pair 521: Type: Forged, Distance: 0.4320
# Pair 522: Type: Forged, Distance: 0.5166
# Pair 523: Type: Forged, Distance: 0.3785
# Pair 524: Type: Forged, Distance: 0.5063
# Pair 525: Type: Forged, Distance: 0.3290
# Pair 526: Type: Forged, Distance: 0.4557
# Pair 527: Type: Forged, Distance: 0.4619
# Pair 528: Type: Forged, Distance: 0.4979
# Pair 529: Type: Forged, Distance: 0.3596
# Pair 530: Type: Forged, Distance: 0.5146
# Pair 531: Type: Forged, Distance: 0.5095
# Pair 532: Type: Forged, Distance: 0.3885
# Pair 533: Type: Forged, Distance: 0.5147
# Pair 534: Type: Forged, Distance: 0.4855
# Pair 535: Type: Forged, Distance: 0.4024
# Pair 536: Type: Forged, Distance: 0.4158
# Pair 537: Type: Forged, Distance: 0.5105
# Pair 538: Type: Forged, Distance: 0.4028
# Pair 539: Type: Forged, Distance: 0.4650
# Pair 540: Type: Forged, Distance: 0.4587
# Pair 541: Type: Forged, Distance: 0.5113
# Pair 542: Type: Forged, Distance: 0.4875
# Pair 543: Type: Forged, Distance: 0.5012
# Pair 544: Type: Forged, Distance: 0.4839
# Pair 545: Type: Forged, Distance: 0.4125
# Pair 546: Type: Forged, Distance: 0.4987
# Pair 547: Type: Forged, Distance: 0.5003
# Pair 548: Type: Forged, Distance: 0.4972
# Pair 549: Type: Forged, Distance: 0.4561
# Pair 550: Type: Forged, Distance: 0.4621
# Pair 551: Type: Forged, Distance: 0.4077
# Pair 552: Type: Forged, Distance: 0.4930
# Pair 553: Type: Forged, Distance: 0.4804
# Pair 554: Type: Forged, Distance: 0.5031
# Pair 555: Type: Forged, Distance: 0.3367
# Pair 556: Type: Forged, Distance: 0.4300
# Pair 557: Type: Forged, Distance: 0.4946
# Pair 558: Type: Forged, Distance: 0.4956
# Pair 559: Type: Forged, Distance: 0.3576
# Pair 560: Type: Forged, Distance: 0.4943
# Pair 561: Type: Forged, Distance: 0.5040
# Pair 562: Type: Forged, Distance: 0.4937
# Pair 563: Type: Forged, Distance: 0.4462
# Pair 564: Type: Forged, Distance: 0.4561
# Pair 565: Type: Forged, Distance: 0.5038
# Pair 566: Type: Forged, Distance: 0.4075
# Pair 567: Type: Forged, Distance: 0.4064
# Pair 568: Type: Forged, Distance: 0.4789
# Pair 569: Type: Forged, Distance: 0.4960
# Pair 570: Type: Forged, Distance: 0.4187
# Pair 571: Type: Forged, Distance: 0.4980
# Pair 572: Type: Forged, Distance: 0.4142
# Pair 573: Type: Forged, Distance: 0.4528
# Pair 574: Type: Forged, Distance: 0.3744
# Pair 575: Type: Forged, Distance: 0.4569
# Pair 576: Type: Forged, Distance: 0.4861
# Pair 577: Type: Forged, Distance: 0.4981
# Pair 578: Type: Forged, Distance: 0.4211
# Pair 579: Type: Forged, Distance: 0.4691
# Pair 580: Type: Forged, Distance: 0.4906
# Pair 581: Type: Forged, Distance: 0.3715
# Pair 582: Type: Forged, Distance: 0.4709
# Pair 583: Type: Forged, Distance: 0.4428
# Pair 584: Type: Forged, Distance: 0.4010
# Pair 585: Type: Forged, Distance: 0.3760
# Pair 586: Type: Forged, Distance: 0.5084
# Pair 587: Type: Forged, Distance: 0.5016
# Pair 588: Type: Forged, Distance: 0.4247
# Pair 589: Type: Forged, Distance: 0.3254
# Pair 590: Type: Forged, Distance: 0.4927
# Pair 591: Type: Forged, Distance: 0.3970
# Pair 592: Type: Forged, Distance: 0.4944
# Pair 593: Type: Forged, Distance: 0.4323
# Pair 594: Type: Forged, Distance: 0.4882
# Pair 595: Type: Forged, Distance: 0.4991
# Pair 596: Type: Forged, Distance: 0.5042
# Pair 597: Type: Forged, Distance: 0.5002
# Pair 598: Type: Forged, Distance: 0.4938
# Pair 599: Type: Forged, Distance: 0.3752
# Pair 600: Type: Forged, Distance: 0.4546
# Pair 601: Type: Forged, Distance: 0.3827
# Pair 602: Type: Forged, Distance: 0.4445
# Pair 603: Type: Forged, Distance: 0.4839
# Pair 604: Type: Forged, Distance: 0.4074
# Pair 605: Type: Forged, Distance: 0.5000
# Pair 606: Type: Forged, Distance: 0.5058
# Pair 607: Type: Forged, Distance: 0.4686
# Pair 608: Type: Forged, Distance: 0.4318
# Pair 609: Type: Forged, Distance: 0.4050
# Pair 610: Type: Forged, Distance: 0.4559
# Pair 611: Type: Forged, Distance: 0.4955
# Pair 612: Type: Forged, Distance: 0.4772
# Pair 613: Type: Forged, Distance: 0.4408
# Pair 614: Type: Forged, Distance: 0.2965
# Pair 615: Type: Forged, Distance: 0.4833
# Pair 616: Type: Forged, Distance: 0.4583
# Pair 617: Type: Forged, Distance: 0.2928
# Pair 618: Type: Forged, Distance: 0.4183
# Pair 619: Type: Forged, Distance: 0.3771
# Pair 620: Type: Forged, Distance: 0.3127
# Pair 621: Type: Forged, Distance: 0.4940
# Pair 622: Type: Forged, Distance: 0.4563
# Pair 623: Type: Forged, Distance: 0.4676
# Pair 624: Type: Forged, Distance: 0.4930
# Pair 625: Type: Forged, Distance: 0.4571
# Pair 626: Type: Forged, Distance: 0.4342
# Pair 627: Type: Forged, Distance: 0.4683
# Pair 628: Type: Forged, Distance: 0.5030
# Pair 629: Type: Forged, Distance: 0.3797
# Pair 630: Type: Forged, Distance: 0.4808
# Pair 631: Type: Forged, Distance: 0.4408
# Pair 632: Type: Forged, Distance: 0.4153
# Pair 633: Type: Forged, Distance: 0.4024
# Pair 634: Type: Forged, Distance: 0.4548
# Pair 635: Type: Forged, Distance: 0.2514
# Pair 636: Type: Forged, Distance: 0.4461
# Pair 637: Type: Forged, Distance: 0.4240
# Pair 638: Type: Forged, Distance: 0.4028
# Pair 639: Type: Forged, Distance: 0.3547
# Pair 640: Type: Forged, Distance: 0.4445
# Pair 641: Type: Forged, Distance: 0.4871
# Pair 642: Type: Forged, Distance: 0.3618
# Pair 643: Type: Forged, Distance: 0.4860
# Pair 644: Type: Forged, Distance: 0.4269
# Pair 645: Type: Forged, Distance: 0.4431
# Pair 646: Type: Forged, Distance: 0.4135
# Pair 647: Type: Forged, Distance: 0.4619
# Pair 648: Type: Forged, Distance: 0.4081
# Pair 649: Type: Forged, Distance: 0.4082
# Pair 650: Type: Forged, Distance: 0.4905
# Pair 651: Type: Forged, Distance: 0.3988
# Pair 652: Type: Forged, Distance: 0.4114
# Pair 653: Type: Forged, Distance: 0.2712
# Pair 654: Type: Forged, Distance: 0.4398
# Pair 655: Type: Forged, Distance: 0.3343
# Pair 656: Type: Forged, Distance: 0.4992
# Pair 657: Type: Forged, Distance: 0.4325
# Pair 658: Type: Forged, Distance: 0.3810
# Pair 659: Type: Forged, Distance: 0.4462
# Pair 660: Type: Forged, Distance: 0.4363
# Pair 661: Type: Forged, Distance: 0.4981
# Pair 662: Type: Forged, Distance: 0.4155
# Pair 663: Type: Forged, Distance: 0.3829
# Pair 664: Type: Forged, Distance: 0.5009
# Pair 665: Type: Forged, Distance: 0.5073
# Pair 666: Type: Forged, Distance: 0.3878
# Pair 667: Type: Forged, Distance: 0.4347
# Pair 668: Type: Forged, Distance: 0.3137
# Pair 669: Type: Forged, Distance: 0.4536
# Pair 670: Type: Forged, Distance: 0.5009
# Pair 671: Type: Forged, Distance: 0.5009
# Pair 672: Type: Forged, Distance: 0.4533
# Pair 673: Type: Forged, Distance: 0.4027
# Pair 674: Type: Forged, Distance: 0.4926
# Pair 675: Type: Forged, Distance: 0.3797
# Pair 676: Type: Forged, Distance: 0.4725
# Pair 677: Type: Forged, Distance: 0.4584
# Pair 678: Type: Forged, Distance: 0.5076
# Pair 679: Type: Forged, Distance: 0.4051
# Pair 680: Type: Forged, Distance: 0.5078
# Pair 681: Type: Forged, Distance: 0.4931
# Pair 682: Type: Forged, Distance: 0.3925
# Pair 683: Type: Forged, Distance: 0.4971
# Pair 684: Type: Forged, Distance: 0.4581
# Pair 685: Type: Forged, Distance: 0.3868
# Pair 686: Type: Forged, Distance: 0.4699
# Pair 687: Type: Forged, Distance: 0.4625
# Pair 688: Type: Forged, Distance: 0.4758
# Pair 689: Type: Forged, Distance: 0.5040
# Pair 690: Type: Forged, Distance: 0.4662
# Pair 691: Type: Forged, Distance: 0.4533
# Pair 692: Type: Forged, Distance: 0.3672
# Pair 693: Type: Forged, Distance: 0.4708
# Pair 694: Type: Forged, Distance: 0.3313
# Pair 695: Type: Forged, Distance: 0.4985
# Pair 696: Type: Forged, Distance: 0.4707
# Pair 697: Type: Forged, Distance: 0.4409
# Pair 698: Type: Forged, Distance: 0.4038
# Pair 699: Type: Forged, Distance: 0.4845
# Pair 700: Type: Forged, Distance: 0.4487
# Pair 701: Type: Forged, Distance: 0.4432
# Pair 702: Type: Forged, Distance: 0.4307
# Pair 703: Type: Forged, Distance: 0.4669
# Pair 704: Type: Forged, Distance: 0.4462
# Pair 705: Type: Forged, Distance: 0.4031
# Pair 706: Type: Forged, Distance: 0.4670
# Pair 707: Type: Forged, Distance: 0.3927
# Pair 708: Type: Forged, Distance: 0.3953
# Pair 709: Type: Forged, Distance: 0.3085
# Pair 710: Type: Forged, Distance: 0.4636
# Pair 711: Type: Forged, Distance: 0.3827
# Pair 712: Type: Forged, Distance: 0.4147
# Pair 713: Type: Forged, Distance: 0.3995
# Pair 714: Type: Forged, Distance: 0.4651
# Pair 715: Type: Forged, Distance: 0.3875
# Pair 716: Type: Forged, Distance: 0.3502
# Pair 717: Type: Forged, Distance: 0.4609
# Pair 718: Type: Forged, Distance: 0.3858
# Pair 719: Type: Forged, Distance: 0.3780
# Pair 720: Type: Forged, Distance: 0.4346
# Pair 721: Type: Forged, Distance: 0.3940
# Pair 722: Type: Forged, Distance: 0.4677
# Pair 723: Type: Forged, Distance: 0.3734
# Pair 724: Type: Forged, Distance: 0.4372
# Pair 725: Type: Forged, Distance: 0.4286
# Pair 726: Type: Forged, Distance: 0.4216
# Pair 727: Type: Forged, Distance: 0.4380
# Pair 728: Type: Forged, Distance: 0.4766
# Pair 729: Type: Forged, Distance: 0.4567
# Pair 730: Type: Forged, Distance: 0.4240
# Pair 731: Type: Forged, Distance: 0.4948
# Pair 732: Type: Forged, Distance: 0.4949
# Pair 733: Type: Forged, Distance: 0.4406
# Pair 734: Type: Forged, Distance: 0.4208
# Pair 735: Type: Forged, Distance: 0.4530
# Pair 736: Type: Forged, Distance: 0.4816
# Pair 737: Type: Forged, Distance: 0.4665
# Pair 738: Type: Forged, Distance: 0.4478
# Pair 739: Type: Forged, Distance: 0.5023
# Pair 740: Type: Forged, Distance: 0.4761
# Pair 741: Type: Forged, Distance: 0.4324
# Pair 742: Type: Forged, Distance: 0.3909
# Pair 743: Type: Forged, Distance: 0.5030
# Pair 744: Type: Forged, Distance: 0.4796
# Pair 745: Type: Forged, Distance: 0.3922
# Pair 746: Type: Forged, Distance: 0.3039
# Pair 747: Type: Forged, Distance: 0.4546
# Pair 748: Type: Forged, Distance: 0.3708
# Pair 749: Type: Forged, Distance: 0.3405
# Pair 750: Type: Forged, Distance: 0.4717
# Pair 751: Type: Forged, Distance: 0.4650
# Pair 752: Type: Forged, Distance: 0.3681
# Pair 753: Type: Forged, Distance: 0.3539
# Pair 754: Type: Forged, Distance: 0.2950
# Pair 755: Type: Forged, Distance: 0.4236
# Pair 756: Type: Forged, Distance: 0.4593
# Pair 757: Type: Forged, Distance: 0.3848
# Pair 758: Type: Forged, Distance: 0.5082
# Pair 759: Type: Forged, Distance: 0.4747
# Pair 760: Type: Forged, Distance: 0.3884
# Pair 761: Type: Forged, Distance: 0.4335
# Pair 762: Type: Forged, Distance: 0.4567
# Pair 763: Type: Forged, Distance: 0.4104
# Pair 764: Type: Forged, Distance: 0.3587
# Pair 765: Type: Forged, Distance: 0.3940
# Pair 766: Type: Forged, Distance: 0.4109
# Pair 767: Type: Forged, Distance: 0.5140
# Pair 768: Type: Forged, Distance: 0.3885
# Pair 769: Type: Forged, Distance: 0.4077
# Pair 770: Type: Forged, Distance: 0.4079
# Pair 771: Type: Forged, Distance: 0.4231
# Pair 772: Type: Forged, Distance: 0.4183
# Pair 773: Type: Forged, Distance: 0.4122
# Pair 774: Type: Forged, Distance: 0.5112
# Pair 775: Type: Forged, Distance: 0.3689
# Pair 776: Type: Forged, Distance: 0.4636
# Pair 777: Type: Forged, Distance: 0.4917
# Pair 778: Type: Forged, Distance: 0.4669
# Pair 779: Type: Forged, Distance: 0.4930
# Pair 780: Type: Forged, Distance: 0.4553
# Pair 781: Type: Forged, Distance: 0.4313
# Pair 782: Type: Forged, Distance: 0.4555
# Pair 783: Type: Forged, Distance: 0.3209
# Pair 784: Type: Forged, Distance: 0.4497
# Pair 785: Type: Forged, Distance: 0.4448
# Pair 786: Type: Forged, Distance: 0.4742
# Pair 787: Type: Forged, Distance: 0.4199
# Pair 788: Type: Forged, Distance: 0.4708
# Pair 789: Type: Forged, Distance: 0.4156
# Pair 790: Type: Forged, Distance: 0.4751
# Pair 791: Type: Forged, Distance: 0.5020
# Pair 792: Type: Forged, Distance: 0.4323
# Pair 793: Type: Forged, Distance: 0.4608
# Pair 794: Type: Forged, Distance: 0.4841
# Pair 795: Type: Forged, Distance: 0.4761
# Pair 796: Type: Forged, Distance: 0.4902
# Pair 797: Type: Forged, Distance: 0.4343
# Pair 798: Type: Forged, Distance: 0.3913
# Pair 799: Type: Forged, Distance: 0.4870
# Pair 800: Type: Forged, Distance: 0.4104
# Pair 801: Type: Forged, Distance: 0.3794
# Pair 802: Type: Forged, Distance: 0.3841
# Pair 803: Type: Forged, Distance: 0.5167
# Pair 804: Type: Forged, Distance: 0.5260
# Pair 805: Type: Forged, Distance: 0.4583
# Pair 806: Type: Forged, Distance: 0.3393
# Pair 807: Type: Forged, Distance: 0.4886
# Pair 808: Type: Forged, Distance: 0.4726
# Pair 809: Type: Forged, Distance: 0.4732
# Pair 810: Type: Forged, Distance: 0.3049
# Pair 811: Type: Forged, Distance: 0.4124
# Pair 812: Type: Forged, Distance: 0.4419
# Pair 813: Type: Forged, Distance: 0.5102
# Pair 814: Type: Forged, Distance: 0.4266
# Pair 815: Type: Forged, Distance: 0.3689
# Pair 816: Type: Forged, Distance: 0.4843
# Pair 817: Type: Forged, Distance: 0.4028
# Pair 818: Type: Forged, Distance: 0.3982
# Pair 819: Type: Forged, Distance: 0.3500
# Pair 820: Type: Forged, Distance: 0.4953
# Pair 821: Type: Forged, Distance: 0.3625
# Pair 822: Type: Forged, Distance: 0.4567
# Pair 823: Type: Forged, Distance: 0.4808
# Pair 824: Type: Forged, Distance: 0.4289
# Pair 825: Type: Forged, Distance: 0.4572
# Pair 826: Type: Forged, Distance: 0.4980
# Pair 827: Type: Forged, Distance: 0.4669
# Pair 828: Type: Forged, Distance: 0.4782
# Pair 829: Type: Forged, Distance: 0.4039
# Pair 830: Type: Forged, Distance: 0.4567
# Pair 831: Type: Forged, Distance: 0.4818
# Pair 832: Type: Forged, Distance: 0.4831
# Pair 833: Type: Forged, Distance: 0.3930
# Pair 834: Type: Forged, Distance: 0.3519
# Pair 835: Type: Forged, Distance: 0.4945
# Pair 836: Type: Forged, Distance: 0.3559
# Pair 837: Type: Forged, Distance: 0.4446
# Pair 838: Type: Forged, Distance: 0.2457
# Pair 839: Type: Forged, Distance: 0.2890
# Pair 840: Type: Forged, Distance: 0.5112
# Pair 841: Type: Forged, Distance: 0.3694
# Pair 842: Type: Forged, Distance: 0.4982
# Pair 843: Type: Forged, Distance: 0.4531
# Pair 844: Type: Forged, Distance: 0.4953
# Pair 845: Type: Forged, Distance: 0.4333
# Pair 846: Type: Forged, Distance: 0.4678
# Pair 847: Type: Forged, Distance: 0.3111
# Pair 848: Type: Forged, Distance: 0.4349
# Pair 849: Type: Forged, Distance: 0.4347
# Pair 850: Type: Forged, Distance: 0.4456
# Pair 851: Type: Forged, Distance: 0.4609
# Pair 852: Type: Forged, Distance: 0.4551
# Pair 853: Type: Forged, Distance: 0.4766
# Pair 854: Type: Forged, Distance: 0.4740
# Pair 855: Type: Forged, Distance: 0.5055
# Pair 856: Type: Forged, Distance: 0.3473
# Pair 857: Type: Forged, Distance: 0.3400
# Pair 858: Type: Forged, Distance: 0.4022
# Pair 859: Type: Forged, Distance: 0.4089
# Pair 860: Type: Forged, Distance: 0.4607
# Pair 861: Type: Forged, Distance: 0.4963
# Pair 862: Type: Forged, Distance: 0.4422
# Pair 863: Type: Forged, Distance: 0.4187
# Pair 864: Type: Forged, Distance: 0.4973
# Pair 865: Type: Forged, Distance: 0.3611
# Pair 866: Type: Forged, Distance: 0.3859
# Pair 867: Type: Forged, Distance: 0.4765
# Pair 868: Type: Forged, Distance: 0.4364
# Pair 869: Type: Forged, Distance: 0.3269
# Pair 870: Type: Forged, Distance: 0.4449
# Pair 871: Type: Forged, Distance: 0.4851
# Pair 872: Type: Forged, Distance: 0.3780
# Pair 873: Type: Forged, Distance: 0.4820
# Pair 874: Type: Forged, Distance: 0.4732
# Pair 875: Type: Forged, Distance: 0.4934
# Pair 876: Type: Forged, Distance: 0.4731
# Pair 877: Type: Forged, Distance: 0.4746
# Pair 878: Type: Forged, Distance: 0.4118
# Pair 879: Type: Forged, Distance: 0.3690
# Pair 880: Type: Forged, Distance: 0.4951
# Pair 881: Type: Forged, Distance: 0.4352
# Pair 882: Type: Forged, Distance: 0.3797
# Pair 883: Type: Forged, Distance: 0.5095
# Pair 884: Type: Forged, Distance: 0.4318
# Pair 885: Type: Forged, Distance: 0.4656
# Pair 886: Type: Forged, Distance: 0.4775
# Pair 887: Type: Forged, Distance: 0.4127
# Pair 888: Type: Forged, Distance: 0.4481
# Pair 889: Type: Forged, Distance: 0.3418
# Pair 890: Type: Forged, Distance: 0.4536
# Pair 891: Type: Forged, Distance: 0.4713
# Pair 892: Type: Forged, Distance: 0.5008
# Pair 893: Type: Forged, Distance: 0.5012
# Pair 894: Type: Forged, Distance: 0.3827
# Pair 895: Type: Forged, Distance: 0.4572
# Pair 896: Type: Forged, Distance: 0.4162
# Pair 897: Type: Forged, Distance: 0.3979
# Pair 898: Type: Forged, Distance: 0.3947
# Pair 899: Type: Forged, Distance: 0.4493
# Pair 900: Type: Forged, Distance: 0.4815
# Pair 901: Type: Forged, Distance: 0.4904
# Pair 902: Type: Forged, Distance: 0.2403
# Pair 903: Type: Forged, Distance: 0.3529
# Pair 904: Type: Forged, Distance: 0.4584
# Pair 905: Type: Forged, Distance: 0.4726
# Pair 906: Type: Forged, Distance: 0.3816
# Pair 907: Type: Forged, Distance: 0.2594
# Pair 908: Type: Forged, Distance: 0.3968
# Pair 909: Type: Forged, Distance: 0.4735
# Pair 910: Type: Forged, Distance: 0.4003
# Pair 911: Type: Forged, Distance: 0.4166
# Pair 912: Type: Forged, Distance: 0.4972
# Pair 913: Type: Forged, Distance: 0.3940
# Pair 914: Type: Forged, Distance: 0.4947
# Pair 915: Type: Forged, Distance: 0.4855
# Pair 916: Type: Forged, Distance: 0.4786
# Pair 917: Type: Forged, Distance: 0.4932
# Pair 918: Type: Forged, Distance: 0.3984
# Pair 919: Type: Forged, Distance: 0.2950
# Pair 920: Type: Forged, Distance: 0.3989
# Pair 921: Type: Forged, Distance: 0.4823
# Pair 922: Type: Forged, Distance: 0.4928
# Pair 923: Type: Forged, Distance: 0.3575
# Pair 924: Type: Forged, Distance: 0.4929
# Pair 925: Type: Forged, Distance: 0.4496
# Pair 926: Type: Forged, Distance: 0.4932
# Pair 927: Type: Forged, Distance: 0.4162
# Pair 928: Type: Forged, Distance: 0.4091
# Pair 929: Type: Forged, Distance: 0.3934
# Pair 930: Type: Forged, Distance: 0.3942
# Pair 931: Type: Forged, Distance: 0.4955
# Pair 932: Type: Forged, Distance: 0.4992
# Pair 933: Type: Forged, Distance: 0.4516
# Pair 934: Type: Forged, Distance: 0.5038
# Pair 935: Type: Forged, Distance: 0.3560
# Pair 936: Type: Forged, Distance: 0.3383
# Pair 937: Type: Forged, Distance: 0.4466
# Pair 938: Type: Forged, Distance: 0.4315
# Pair 939: Type: Forged, Distance: 0.4917
# Pair 940: Type: Forged, Distance: 0.3957
# Pair 941: Type: Forged, Distance: 0.3988
# Pair 942: Type: Forged, Distance: 0.3689
# Pair 943: Type: Forged, Distance: 0.4140
# Pair 944: Type: Forged, Distance: 0.4173
# Pair 945: Type: Forged, Distance: 0.3909
# Pair 946: Type: Forged, Distance: 0.4359
# Pair 947: Type: Forged, Distance: 0.3734
# Pair 948: Type: Forged, Distance: 0.4757
# Pair 949: Type: Forged, Distance: 0.3701
# Pair 950: Type: Forged, Distance: 0.5095
# Pair 951: Type: Forged, Distance: 0.4314
# Pair 952: Type: Forged, Distance: 0.4359
# Pair 953: Type: Forged, Distance: 0.4347
# Pair 954: Type: Forged, Distance: 0.4947
# Pair 955: Type: Forged, Distance: 0.4945
# Pair 956: Type: Forged, Distance: 0.4803
# Pair 957: Type: Forged, Distance: 0.3848
# Pair 958: Type: Forged, Distance: 0.3581
# Pair 959: Type: Forged, Distance: 0.3672
# Pair 960: Type: Forged, Distance: 0.4461
# Pair 961: Type: Forged, Distance: 0.3860
# Pair 962: Type: Forged, Distance: 0.4011
# Pair 963: Type: Forged, Distance: 0.3856
# Pair 964: Type: Forged, Distance: 0.4329
# Pair 965: Type: Forged, Distance: 0.4959
# Pair 966: Type: Forged, Distance: 0.4103
# Pair 967: Type: Forged, Distance: 0.3135
# Pair 968: Type: Forged, Distance: 0.4933
# Pair 969: Type: Forged, Distance: 0.3513
# Pair 970: Type: Forged, Distance: 0.4799
# Pair 971: Type: Forged, Distance: 0.4427
# Pair 972: Type: Forged, Distance: 0.2824
# Pair 973: Type: Forged, Distance: 0.5108
# Pair 974: Type: Forged, Distance: 0.3856
# Pair 975: Type: Forged, Distance: 0.4992
# Pair 976: Type: Forged, Distance: 0.4924
# Pair 977: Type: Forged, Distance: 0.3418
# Pair 978: Type: Forged, Distance: 0.3399
# Pair 979: Type: Forged, Distance: 0.4132
# Pair 980: Type: Forged, Distance: 0.4039
# Pair 981: Type: Forged, Distance: 0.3672
# Pair 982: Type: Forged, Distance: 0.4742
# Pair 983: Type: Forged, Distance: 0.4966
# Pair 984: Type: Forged, Distance: 0.3497
# Pair 985: Type: Forged, Distance: 0.4022
# Pair 986: Type: Forged, Distance: 0.4879
# Pair 987: Type: Forged, Distance: 0.4201
# Pair 988: Type: Forged, Distance: 0.4268
# Pair 989: Type: Forged, Distance: 0.3885
# Pair 990: Type: Forged, Distance: 0.5074
# Pair 991: Type: Forged, Distance: 0.4268
# Pair 992: Type: Forged, Distance: 0.3137
# Pair 993: Type: Forged, Distance: 0.4647
# Pair 994: Type: Forged, Distance: 0.4767
# Pair 995: Type: Forged, Distance: 0.3280
# Pair 996: Type: Forged, Distance: 0.4595
# Pair 997: Type: Forged, Distance: 0.5027
# Pair 998: Type: Forged, Distance: 0.3588
# Pair 999: Type: Forged, Distance: 0.4721
# Pair 1000: Type: Forged, Distance: 0.3607
# Pair 1001: Type: Forged, Distance: 0.4218
# Pair 1002: Type: Forged, Distance: 0.4182
# Pair 1003: Type: Forged, Distance: 0.4662
# Pair 1004: Type: Forged, Distance: 0.4883
# Pair 1005: Type: Forged, Distance: 0.4847
# Pair 1006: Type: Forged, Distance: 0.4254
# Pair 1007: Type: Forged, Distance: 0.4992
# Pair 1008: Type: Forged, Distance: 0.4772
# Pair 1009: Type: Forged, Distance: 0.4690
# Pair 1010: Type: Forged, Distance: 0.4541
# Pair 1011: Type: Forged, Distance: 0.3931
# Pair 1012: Type: Forged, Distance: 0.4869
# Pair 1013: Type: Forged, Distance: 0.4104
# Pair 1014: Type: Forged, Distance: 0.5075
# Pair 1015: Type: Forged, Distance: 0.4870
# Pair 1016: Type: Forged, Distance: 0.3689
# Pair 1017: Type: Forged, Distance: 0.4711
# Pair 1018: Type: Forged, Distance: 0.4921
# Pair 1019: Type: Forged, Distance: 0.4808
# Pair 1020: Type: Forged, Distance: 0.4312
# Pair 1021: Type: Forged, Distance: 0.4091
# Pair 1022: Type: Forged, Distance: 0.3827
# Pair 1023: Type: Forged, Distance: 0.4530
# Pair 1024: Type: Forged, Distance: 0.3686

# %%
# Print paths of all images in the test set
for orig_group, forg_group in zip(orig_test, forg_test):
    print("Originals:")
    for img_path in orig_group:
        print(img_path)
    print("Forged:")
    for img_path in forg_group:
        print(img_path)
# Out:
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-05.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-12.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_3.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_10.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_9.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_19.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_4.png
# Forged:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_8.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_21.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_19.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_17.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_13.png
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-06.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-10.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-21.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-29.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-12.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-12.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-19.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-29.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-27.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-23.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-16.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-19.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-04.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-13.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-15.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-14.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-09.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-26.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-02.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-24.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-14.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-05.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-28.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-17.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-02.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-23.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-16.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-24.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-12.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-03.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-16.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-10.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-13.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-15.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-05.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-22.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-07.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-20.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-05.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_6.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_21.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_17.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_10.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_1.png
# Forged:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_4.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_20.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_2.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_16.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_13.png
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-05.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-02.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-24.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-07.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_24.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_17.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_13.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_2.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_11.png
# Forged:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_5.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_6.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_14.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_3.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_9.png
# Originals:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_4.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_17.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_10.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_12.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_5.png
# Forged:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_20.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_7.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_6.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_2.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_22.png
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-15.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-22.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-03.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-30.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-23.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-30.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-13.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-21.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-18.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-04.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-30.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-11.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-02.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-23.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-06.tif
