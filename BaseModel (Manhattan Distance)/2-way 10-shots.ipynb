# %% [markdown]
# # Multilingual Offline Forged  Signature Using Siamese Neural Network and Few-Shot Learning

# %% [markdown]
# 2-way 10-shots

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)

# %%
import numpy as np
import os
import cv2
import itertools
import random

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
import tensorflow as tf

from keras import backend as K
from keras.optimizers import Adam
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, GlobalAveragePooling2D, Subtract
from keras.layers import BatchNormalization, Dropout
from keras.models import Model, Sequential
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.applications import DenseNet121
from keras.applications import ResNet50V2

import matplotlib.pyplot as plt
import numpy as np
from skimage.metrics import structural_similarity as ssim

# %%
# Paths to Datasets
cedar_path = "/content/drive/MyDrive/Multilingual dataset/CEDAR"
bengali_path = "/content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali"
hindi_path = "/content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi"

# All the images will be converted to the same size before processing
img_h, img_w = 120, 120

# Preprocessing Function
def preprocess_image(img_path):
    image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read image in grayscale
    if image is None or len(image) == 0 or image.shape[0] == 0 or image.shape[1] == 0:
        print(f"Error: Image {img_path} is empty or None or has invalid dimensions.")
        return None
    image = cv2.resize(image, (img_h, img_w))
    image = cv2.merge((image, image, image))  # Convert grayscale to RGB
    image = image.astype('float32') / 255.0  # Normalize pixel values
    return image

# Load Data Function
def load_data(path, forged_count, genuine_count):
    dir_list = next(os.walk(path))[1]
    orig_groups, forg_groups = [], []
    for directory in dir_list:
        images = os.listdir(os.path.join(path, directory))
        images.sort()
        images = [os.path.join(path, directory, x) for x in images]
        forg_groups.append(images[:forged_count])
        orig_groups.append(images[forged_count:forged_count + genuine_count])
    return orig_groups, forg_groups

# Number of shots (images) for each class
shots_per_class = 10

# Total Number of genuine and forged images per folder of CEDAR, Bengali, and Hindi datasets
cedar_forged_count = 24
cedar_genuine_count = 24
bengali_forged_count = 30
bengali_genuine_count = 24
hindi_forged_count = 30
hindi_genuine_count = 24

# Load data with specified counts
orig_cedar, forg_cedar = load_data(cedar_path, cedar_forged_count, cedar_genuine_count)
orig_bengali, forg_bengali = load_data(bengali_path, bengali_forged_count, bengali_genuine_count)
orig_hindi, forg_hindi = load_data(hindi_path, hindi_forged_count, hindi_genuine_count)

# Randomly choose N-shots from each folder
random.seed(42)  # For reproducibility
random_forg_cedar = [random.sample(forg, shots_per_class) for forg in forg_cedar]
random_orig_cedar = [random.sample(orig, shots_per_class) for orig in orig_cedar]
random_forg_bengali = [random.sample(forg, shots_per_class) for forg in forg_bengali]
random_orig_bengali = [random.sample(orig, shots_per_class) for orig in orig_bengali]
random_forg_hindi = [random.sample(forg, shots_per_class) for forg in forg_hindi]
random_orig_hindi = [random.sample(orig, shots_per_class) for orig in orig_hindi]

# Combine Data
orig_groups = random_orig_cedar + random_orig_bengali + random_orig_hindi
forg_groups = random_forg_cedar + random_forg_bengali + random_forg_hindi

# Split Data into Train, Validation, and Test Sets
orig_train, orig_val_test, forg_train, forg_val_test = train_test_split(orig_groups, forg_groups, test_size=0.2, random_state=42)
orig_val, orig_test, forg_val, forg_test = train_test_split(orig_val_test, forg_val_test, test_size=0.5, random_state=42)

# Generate Batch Function
def generate_batch(orig_groups, forg_groups, batch_size=32):
    while True:
        pairs = [np.zeros((batch_size, img_h, img_w, 3)) for _ in range(2)]
        targets = np.zeros((batch_size,))

        for i in range(batch_size):
            if i < batch_size // 2:
                # Genuine-Genuine pairs
                pair_idx = np.random.randint(len(orig_groups), size=2)
                pair = (np.random.choice(orig_groups[pair_idx[0]]), np.random.choice(orig_groups[pair_idx[1]]))
                targets[i] = 1
            else:
                # Genuine-Forged pairs
                orig_idx = np.random.randint(len(orig_groups))
                orig = np.random.choice(orig_groups[orig_idx])
                forg = np.random.choice(forg_groups[orig_idx])
                pair = (orig, forg)
                targets[i] = 0

            img1 = preprocess_image(pair[0])
            img2 = preprocess_image(pair[1])

            pairs[0][i, :, :, :] = img1
            pairs[1][i, :, :, :] = img2

        yield pairs, targets

# Define batch size and generators
batch_size = 32
train_batch_generator = generate_batch(orig_train, forg_train, batch_size=batch_size)
val_batch_generator = generate_batch(orig_val_test, forg_val_test, batch_size=batch_size)
test_batch_generator = generate_batch(orig_test, forg_test, batch_size=batch_size)

def get_siamese_model(input_shape):
    input_a = Input(shape=input_shape)
    input_b = Input(shape=input_shape)

    # Base CNN model
    base_model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu')
    ])

    processed_a = base_model(input_a)
    processed_b = base_model(input_b)

    L1_distance = Lambda(lambda tensors: K.abs(tensors[0] - tensors[1]))([processed_a, processed_b])
    similarity = Dense(1, activation='sigmoid')(L1_distance)

    model = Model(inputs=[input_a, input_b], outputs=similarity)
    return model

input_shape = (img_h, img_w, 3)
model = get_siamese_model(input_shape)
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=1e-4), metrics=['accuracy'])
# Define Callbacks
callbacks = [
    EarlyStopping(patience=4, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint('/content/drive/MyDrive/Multilingual dataset/Weights/2-ways 10-shots/2-ways 10shots-{epoch:03d}.h5',
                    verbose=1, save_best_only=True, save_weights_only=True)
]

# Train Model
num_train_samples = sum(len(group) for group in orig_train + forg_train)
num_val_samples = sum(len(group) for group in orig_val_test + forg_val_test)
steps_per_epoch_train = max(1, num_train_samples // batch_size)
steps_per_epoch_val = max(1, num_val_samples // batch_size)

results = model.fit(
    train_batch_generator,
    steps_per_epoch=steps_per_epoch_train,
    epochs=5,
    validation_data=val_batch_generator,
    validation_steps=steps_per_epoch_val,
    callbacks=callbacks
)
# Out:
# Epoch 1/5
# 157/157 [==============================] - ETA: 0s - loss: 0.5898 - accuracy: 0.6336
# Epoch 1: val_loss improved from inf to 0.53454, saving model to /content/drive/MyDrive/Multilingual dataset/Weights/2-ways 10-shots/2-ways 10shots-001.h5
# 157/157 [==============================] - 1396s 9s/step - loss: 0.5898 - accuracy: 0.6336 - val_loss: 0.5345 - val_accuracy: 0.6955 - lr: 1.0000e-04
# Epoch 2/5
# 157/157 [==============================] - ETA: 0s - loss: 0.4510 - accuracy: 0.7635
# Epoch 2: val_loss did not improve from 0.53454
# 157/157 [==============================] - 473s 3s/step - loss: 0.4510 - accuracy: 0.7635 - val_loss: 0.5433 - val_accuracy: 0.7027 - lr: 1.0000e-04
# Epoch 3/5
# 157/157 [==============================] - ETA: 0s - loss: 0.4019 - accuracy: 0.8065
# Epoch 3: val_loss improved from 0.53454 to 0.50235, saving model to /content/drive/MyDrive/Multilingual dataset/Weights/2-ways 10-shots/2-ways 10shots-003.h5
# 157/157 [==============================] - 453s 3s/step - loss: 0.4019 - accuracy: 0.8065 - val_loss: 0.5024 - val_accuracy: 0.7380 - lr: 1.0000e-04
# Epoch 4/5
# 157/157 [==============================] - ETA: 0s - loss: 0.3511 - accuracy: 0.8426
# Epoch 4: val_loss did not improve from 0.50235
# 157/157 [==============================] - 412s 3s/step - loss: 0.3511 - accuracy: 0.8426 - val_loss: 0.5707 - val_accuracy: 0.7075 - lr: 1.0000e-04
# Epoch 5/5
# 157/157 [==============================] - ETA: 0s - loss: 0.3222 - accuracy: 0.8637
# Epoch 5: val_loss did not improve from 0.50235
# 157/157 [==============================] - 412s 3s/step - loss: 0.3222 - accuracy: 0.8637 - val_loss: 0.5220 - val_accuracy: 0.7316 - lr: 1.0000e-04

# %%
# Summary of the model
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 120, 120, 3)]        0         []
#
#  input_4 (InputLayer)        [(None, 120, 120, 3)]        0         []
#
#  sequential_1 (Sequential)   (None, 512)                  1116934   ['input_3[0][0]',
#                                                           4          'input_4[0][0]']
#
#  lambda_1 (Lambda)           (None, 512)                  0         ['sequential_1[0][0]',
#                                                                      'sequential_1[1][0]']
#
#  dense_3 (Dense)             (None, 1)                    513       ['lambda_1[0][0]']
#
# ==================================================================================================
# Total params: 11169857 (42.61 MB)
# Trainable params: 11169857 (42.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
train_loss = results.history['loss']
val_loss = results.history['val_loss']

# Plot training and validation loss
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Load best weights
model.load_weights('/content/drive/MyDrive/Multilingual dataset/Weights/2-ways 10-shots/2-ways 10shots-003.h5')

# %%
# Example: Predict on test data (replace with actual test data)
test_batch_inputs, test_batch_labels = next(test_batch_generator)
predictions = model.predict(test_batch_inputs)

# Function to compute ROC curve
def compute_roc_curve(predictions, labels):
    fpr, tpr, thresholds = roc_curve(labels, predictions)  # Use predictions directly
    roc_auc = auc(fpr, tpr)
    return fpr, tpr, thresholds, roc_auc

# Compute ROC curve
fpr, tpr, thresholds, roc_auc = compute_roc_curve(predictions, test_batch_labels)

# Find the optimal threshold using Youden's J statistic
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]

# Apply the optimal threshold to predictions
predictions_binary = (predictions >= optimal_threshold).astype(int)  # Use '>=' for similarity scores

# Calculate metrics using the optimal threshold
accuracy = accuracy_score(test_batch_labels, predictions_binary)
precision = precision_score(test_batch_labels, predictions_binary)
recall = recall_score(test_batch_labels, predictions_binary)
f1 = f1_score(test_batch_labels, predictions_binary)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
print("Optimal Threshold:", optimal_threshold)
print("ROC AUC:", roc_auc)
# Out:
# 1/1 [==============================] - 1s 910ms/step
# Accuracy: 0.875
# Precision: 1.0
# Recall: 0.75
# F1-Score: 0.8571428571428571
# Optimal Threshold: 0.8691411
# ROC AUC: 0.80859375

# %%
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(test_batch_labels, predictions)

# Compute ROC AUC
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
def display_genuine_forged_with_ssim(model, test_batch_generator, num_pairs=16):
    test_batch_inputs, test_batch_labels = next(test_batch_generator)
    predictions = model.predict(test_batch_inputs)

    fig, axes = plt.subplots(num_pairs, 2, figsize=(8, 2*num_pairs))
    genuine_forged_pairs = [(test_batch_inputs[0][i], test_batch_inputs[1][i], test_batch_labels[i]) for i in range(len(test_batch_labels)) if test_batch_labels[i] == 0]

    ssim_scores = []
    for i in range(num_pairs):
        img1, img2, label = genuine_forged_pairs[i]
        ssim_score = ssim(img1, img2, multichannel=True)
        ssim_scores.append(ssim_score)

        axes[i, 0].imshow(img1)
        axes[i, 0].set_title(f"Image 1")
        axes[i, 0].axis('off')

        axes[i, 1].imshow(img2)
        axes[i, 1].set_title(f"Image 2 (SSIM: {ssim_score:.4f})")
        axes[i, 1].axis('off')

    plt.tight_layout()
    plt.show()

    # Calculate average SSIM score
    average_ssim = np.mean(ssim_scores)
    print("Average SSIM score:", average_ssim)

# Call the function to display genuine-forged image pairs with SSIM scores and print the average SSIM score
display_genuine_forged_with_ssim(model, test_batch_generator)
# Out:
# 1/1 [==============================] - 1s 788ms/step
# <ipython-input-112-f8cf05e75744>:11: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   ssim_score = ssim(img1, img2, multichannel=True)
# Average SSIM score: 0.7402182251071903

# %% [markdown]
# **Above Threshold:** If the similarity score is above the threshold, classify the pair as similar.
#
#
# **Below Threshold:** If the similarity score is below the threshold, classify the pair as dissimilar.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
import math

# %%
# Randomly choose N-shots from each folder
random.seed(42)  # For reproducibility
support_forg_cedar = [random.sample(forg, shots_per_class) for forg in forg_cedar]
support_orig_cedar = [random.sample(orig, shots_per_class) for orig in orig_cedar]
support_forg_bengali = [random.sample(forg, shots_per_class) for forg in forg_bengali]
support_orig_bengali = [random.sample(orig, shots_per_class) for orig in orig_bengali]
support_forg_hindi = [random.sample(forg, shots_per_class) for forg in forg_hindi]
support_orig_hindi = [random.sample(orig, shots_per_class) for orig in orig_hindi]

# Combine support sets
support_orig_groups = support_orig_cedar + support_orig_bengali + support_orig_hindi
support_forg_groups = support_forg_cedar + support_forg_bengali + support_forg_hindi

# Initialize list to store query images and their corresponding support sets
query_image_support_pairs = []

# Iterate over each folder and select one query image not in support set and pair it with its support set
for orig_group, forg_group, support_orig, support_forg in zip(orig_cedar + orig_bengali + orig_hindi,
                                                              forg_cedar + forg_bengali + forg_hindi,
                                                              support_orig_groups, support_forg_groups):
    # Select one query image not in support set for original and forged images
    for orig_img in orig_group:
        if orig_img not in support_orig:
            query_image_support_pairs.append((orig_img, support_orig, support_forg))
            break  # Move to the next folder after selecting one query image

    for forg_img in forg_group:
        if forg_img not in support_forg:
            query_image_support_pairs.append((forg_img, support_orig, support_forg))
            break  # Move to the next folder after selecting one query image

print(f"Number of query images paired with their support sets: {len(query_image_support_pairs)}")
# Out:
# Number of query images paired with their support sets: 630

# %% [markdown]
# the mean similarity score for genuine images and the mean similarity score for forged images are computed.
#
# mean scores are compared to the optimal threshold to determine if the overall similarity is considered "Similar" or "Dissimilar".

# %% [markdown]
# 1. Compute similarity scores for each individual support image (both genuine and forged).
# 2. Calculate the mean similarity score for genuine images.
# 3. Calculate the mean similarity score for forged images.
# 4. Determine the optimal threshold based on the mean similarity scores.
# 5. Compare the mean similarity scores to the optimal threshold.
# 6. Classify the query image as "Similar" if the mean similarity score is greater than or equal to the threshold, otherwise classify it as "Dissimilar".

# %%
# Inference function
def k_shot_inference(model, support_set_orig, support_set_forg, query_image, img_h, img_w):
    similarities_orig = []
    similarities_forg = []

    # Compute similarity scores for original images
    for support_image_orig in support_set_orig:
        img1 = preprocess_image(support_image_orig)
        img1 = img1.reshape(1, img_h, img_w, 3)
        img2 = preprocess_image(query_image)
        img2 = img2.reshape(1, img_h, img_w, 3)
        similarity_score_orig = model.predict([img1, img2])[0][0]
        similarities_orig.append(similarity_score_orig)

    # Compute similarity scores for forged images
    for support_image_forg in support_set_forg:
        img1 = preprocess_image(support_image_forg)
        img1 = img1.reshape(1, img_h, img_w, 3)
        img2 = preprocess_image(query_image)
        img2 = img2.reshape(1, img_h, img_w, 3)
        similarity_score_forg = model.predict([img1, img2])[0][0]
        similarities_forg.append(similarity_score_forg)

    return similarities_orig, similarities_forg

# Display function
def show_similarity_score(model, query_image_support_pairs, img_h, img_w):
    # Select one random query image and its corresponding support sets
    query_image, support_set_orig, support_set_forg = random.choice(query_image_support_pairs)
    query_image_name = query_image.split('/')[-1]

    # Compute similarity scores
    similarities_orig, similarities_forg = k_shot_inference(
        model, support_set_orig, support_set_forg, query_image, img_h, img_w
    )

    # Compute mean similarity scores
    genuine_score = np.mean(similarities_orig)
    forged_score = np.mean(similarities_forg)

    # Determine optimal threshold based on the support sets
    optimal_threshold = (genuine_score + forged_score) / 2

    # Determine predicted class
    predicted_class = 0 if genuine_score >= forged_score else 1
    similarity_score = genuine_score if predicted_class == 0 else forged_score
    similarity = "Similar" if similarity_score >= optimal_threshold else "Dissimilar"

    # Display the query image
    plt.figure(figsize=(8, 6))
    plt.subplot(2, 1, 1)
    plt.imshow(preprocess_image(query_image), cmap='gray')
    plt.title(f'Query Image ({query_image_name})')
    plt.axis('off')

    # Add predicted class and similarity text
    plt.text(0.02, 0.02, f'Predicted Class: {"Genuine" if predicted_class == 0 else "Forged"}', ha='left', va='bottom', transform=plt.gca().transAxes)
    plt.text(0.02, 0.92, f'Similarity: {similarity}', ha='left', va='top', transform=plt.gca().transAxes)

    # Display the similarity scores bar chart
    plt.subplot(2, 1, 2)
    bar_labels = ['Genuine', 'Forged']
    bar_scores = [genuine_score, forged_score]
    bar_colors = ['orange' if score >= optimal_threshold else 'red' for score in bar_scores]
    plt.bar(bar_labels, bar_scores, color=bar_colors)
    plt.axhline(y=optimal_threshold, color='black', linestyle='--', linewidth=1)
    plt.title('Similarity Scores')
    plt.ylabel('Score')

    # Add average similarity scores text
    plt.text(-0.1, genuine_score, f'Average Genuine Score: {genuine_score:.2f}', ha='center')
    plt.text(1, forged_score, f'Average Forged Score: {forged_score:.2f}', ha='center')

plt.tight_layout()
plt.show()
# Perform inference and display one result
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 42ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 70ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 66ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 65ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step

# %%
show_similarity_score(model, query_image_support_pairs, img_h, img_w)
# Out:
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step

# %%
# Predict on test data
predictions = model.predict(test_batch_generator, steps=len(orig_test))

# Extract distances from predictions
distances = predictions.flatten()

# Print distances between pairs of images
for i, distance in enumerate(distances):
    pair_type = "Genuine" if i < len(distances) // 2 else "Forged"
    print(f"Pair {i+1}: Type: {pair_type}, Distance: {distance:.4f}")
# Out:
# 32/32 [==============================] - 32s 999ms/step
# Pair 1: Type: Genuine, Distance: 1.0000
# Pair 2: Type: Genuine, Distance: 0.4257
# Pair 3: Type: Genuine, Distance: 0.9999
# Pair 4: Type: Genuine, Distance: 0.9438
# Pair 5: Type: Genuine, Distance: 0.4461
# Pair 6: Type: Genuine, Distance: 0.9947
# Pair 7: Type: Genuine, Distance: 0.3174
# Pair 8: Type: Genuine, Distance: 0.9904
# Pair 9: Type: Genuine, Distance: 0.6952
# Pair 10: Type: Genuine, Distance: 0.5974
# Pair 11: Type: Genuine, Distance: 0.8761
# Pair 12: Type: Genuine, Distance: 0.9996
# Pair 13: Type: Genuine, Distance: 0.7599
# Pair 14: Type: Genuine, Distance: 0.2693
# Pair 15: Type: Genuine, Distance: 0.2084
# Pair 16: Type: Genuine, Distance: 0.9368
# Pair 17: Type: Genuine, Distance: 0.8320
# Pair 18: Type: Genuine, Distance: 0.6828
# Pair 19: Type: Genuine, Distance: 0.3706
# Pair 20: Type: Genuine, Distance: 0.7997
# Pair 21: Type: Genuine, Distance: 0.4084
# Pair 22: Type: Genuine, Distance: 0.3909
# Pair 23: Type: Genuine, Distance: 0.6462
# Pair 24: Type: Genuine, Distance: 0.1252
# Pair 25: Type: Genuine, Distance: 0.3498
# Pair 26: Type: Genuine, Distance: 0.5511
# Pair 27: Type: Genuine, Distance: 0.4662
# Pair 28: Type: Genuine, Distance: 0.1876
# Pair 29: Type: Genuine, Distance: 0.4367
# Pair 30: Type: Genuine, Distance: 0.1913
# Pair 31: Type: Genuine, Distance: 0.2372
# Pair 32: Type: Genuine, Distance: 0.5210
# Pair 33: Type: Genuine, Distance: 0.5171
# Pair 34: Type: Genuine, Distance: 0.3806
# Pair 35: Type: Genuine, Distance: 0.2034
# Pair 36: Type: Genuine, Distance: 0.8633
# Pair 37: Type: Genuine, Distance: 0.5255
# Pair 38: Type: Genuine, Distance: 0.9044
# Pair 39: Type: Genuine, Distance: 0.1376
# Pair 40: Type: Genuine, Distance: 0.8930
# Pair 41: Type: Genuine, Distance: 0.9964
# Pair 42: Type: Genuine, Distance: 0.3217
# Pair 43: Type: Genuine, Distance: 0.9956
# Pair 44: Type: Genuine, Distance: 0.7828
# Pair 45: Type: Genuine, Distance: 0.9998
# Pair 46: Type: Genuine, Distance: 0.5923
# Pair 47: Type: Genuine, Distance: 0.6840
# Pair 48: Type: Genuine, Distance: 0.8698
# Pair 49: Type: Genuine, Distance: 0.4549
# Pair 50: Type: Genuine, Distance: 0.0775
# Pair 51: Type: Genuine, Distance: 0.4365
# Pair 52: Type: Genuine, Distance: 0.4902
# Pair 53: Type: Genuine, Distance: 0.0198
# Pair 54: Type: Genuine, Distance: 0.3684
# Pair 55: Type: Genuine, Distance: 0.3648
# Pair 56: Type: Genuine, Distance: 0.6512
# Pair 57: Type: Genuine, Distance: 0.3502
# Pair 58: Type: Genuine, Distance: 0.2069
# Pair 59: Type: Genuine, Distance: 0.8601
# Pair 60: Type: Genuine, Distance: 0.0323
# Pair 61: Type: Genuine, Distance: 0.5923
# Pair 62: Type: Genuine, Distance: 0.1589
# Pair 63: Type: Genuine, Distance: 0.3942
# Pair 64: Type: Genuine, Distance: 0.8521
# Pair 65: Type: Genuine, Distance: 0.1211
# Pair 66: Type: Genuine, Distance: 0.5593
# Pair 67: Type: Genuine, Distance: 0.9994
# Pair 68: Type: Genuine, Distance: 0.1362
# Pair 69: Type: Genuine, Distance: 0.9830
# Pair 70: Type: Genuine, Distance: 0.4685
# Pair 71: Type: Genuine, Distance: 0.7678
# Pair 72: Type: Genuine, Distance: 0.2613
# Pair 73: Type: Genuine, Distance: 0.3978
# Pair 74: Type: Genuine, Distance: 0.5455
# Pair 75: Type: Genuine, Distance: 0.5771
# Pair 76: Type: Genuine, Distance: 0.7467
# Pair 77: Type: Genuine, Distance: 0.3502
# Pair 78: Type: Genuine, Distance: 0.9997
# Pair 79: Type: Genuine, Distance: 0.9993
# Pair 80: Type: Genuine, Distance: 0.3205
# Pair 81: Type: Genuine, Distance: 0.3131
# Pair 82: Type: Genuine, Distance: 0.3718
# Pair 83: Type: Genuine, Distance: 0.0086
# Pair 84: Type: Genuine, Distance: 0.8525
# Pair 85: Type: Genuine, Distance: 0.3890
# Pair 86: Type: Genuine, Distance: 0.2755
# Pair 87: Type: Genuine, Distance: 0.3741
# Pair 88: Type: Genuine, Distance: 0.3005
# Pair 89: Type: Genuine, Distance: 0.0020
# Pair 90: Type: Genuine, Distance: 0.0048
# Pair 91: Type: Genuine, Distance: 0.7916
# Pair 92: Type: Genuine, Distance: 0.6675
# Pair 93: Type: Genuine, Distance: 0.0343
# Pair 94: Type: Genuine, Distance: 0.0862
# Pair 95: Type: Genuine, Distance: 0.6828
# Pair 96: Type: Genuine, Distance: 0.6314
# Pair 97: Type: Genuine, Distance: 0.7458
# Pair 98: Type: Genuine, Distance: 0.9984
# Pair 99: Type: Genuine, Distance: 0.9995
# Pair 100: Type: Genuine, Distance: 0.6894
# Pair 101: Type: Genuine, Distance: 0.6211
# Pair 102: Type: Genuine, Distance: 0.8039
# Pair 103: Type: Genuine, Distance: 0.9992
# Pair 104: Type: Genuine, Distance: 0.0948
# Pair 105: Type: Genuine, Distance: 0.8679
# Pair 106: Type: Genuine, Distance: 0.3874
# Pair 107: Type: Genuine, Distance: 0.9746
# Pair 108: Type: Genuine, Distance: 0.5863
# Pair 109: Type: Genuine, Distance: 0.2573
# Pair 110: Type: Genuine, Distance: 0.2707
# Pair 111: Type: Genuine, Distance: 1.0000
# Pair 112: Type: Genuine, Distance: 0.9999
# Pair 113: Type: Genuine, Distance: 0.4226
# Pair 114: Type: Genuine, Distance: 0.6991
# Pair 115: Type: Genuine, Distance: 0.0329
# Pair 116: Type: Genuine, Distance: 0.0803
# Pair 117: Type: Genuine, Distance: 0.6272
# Pair 118: Type: Genuine, Distance: 0.3921
# Pair 119: Type: Genuine, Distance: 0.3174
# Pair 120: Type: Genuine, Distance: 0.1011
# Pair 121: Type: Genuine, Distance: 0.2676
# Pair 122: Type: Genuine, Distance: 0.5374
# Pair 123: Type: Genuine, Distance: 0.0446
# Pair 124: Type: Genuine, Distance: 0.3471
# Pair 125: Type: Genuine, Distance: 0.8713
# Pair 126: Type: Genuine, Distance: 0.1784
# Pair 127: Type: Genuine, Distance: 0.4474
# Pair 128: Type: Genuine, Distance: 0.4945
# Pair 129: Type: Genuine, Distance: 0.8541
# Pair 130: Type: Genuine, Distance: 0.9941
# Pair 131: Type: Genuine, Distance: 0.7553
# Pair 132: Type: Genuine, Distance: 0.9613
# Pair 133: Type: Genuine, Distance: 0.5946
# Pair 134: Type: Genuine, Distance: 0.2947
# Pair 135: Type: Genuine, Distance: 0.6806
# Pair 136: Type: Genuine, Distance: 1.0000
# Pair 137: Type: Genuine, Distance: 0.6500
# Pair 138: Type: Genuine, Distance: 0.4188
# Pair 139: Type: Genuine, Distance: 0.8502
# Pair 140: Type: Genuine, Distance: 0.9986
# Pair 141: Type: Genuine, Distance: 0.1875
# Pair 142: Type: Genuine, Distance: 0.9897
# Pair 143: Type: Genuine, Distance: 0.9851
# Pair 144: Type: Genuine, Distance: 0.9651
# Pair 145: Type: Genuine, Distance: 0.2166
# Pair 146: Type: Genuine, Distance: 0.6675
# Pair 147: Type: Genuine, Distance: 0.6417
# Pair 148: Type: Genuine, Distance: 0.2300
# Pair 149: Type: Genuine, Distance: 0.3015
# Pair 150: Type: Genuine, Distance: 0.0116
# Pair 151: Type: Genuine, Distance: 0.1375
# Pair 152: Type: Genuine, Distance: 0.4490
# Pair 153: Type: Genuine, Distance: 0.2935
# Pair 154: Type: Genuine, Distance: 0.9519
# Pair 155: Type: Genuine, Distance: 0.2853
# Pair 156: Type: Genuine, Distance: 0.5676
# Pair 157: Type: Genuine, Distance: 0.6489
# Pair 158: Type: Genuine, Distance: 0.6461
# Pair 159: Type: Genuine, Distance: 0.3213
# Pair 160: Type: Genuine, Distance: 0.5193
# Pair 161: Type: Genuine, Distance: 0.2362
# Pair 162: Type: Genuine, Distance: 0.7141
# Pair 163: Type: Genuine, Distance: 0.9430
# Pair 164: Type: Genuine, Distance: 0.9995
# Pair 165: Type: Genuine, Distance: 0.6863
# Pair 166: Type: Genuine, Distance: 0.7851
# Pair 167: Type: Genuine, Distance: 0.9996
# Pair 168: Type: Genuine, Distance: 0.4922
# Pair 169: Type: Genuine, Distance: 0.4987
# Pair 170: Type: Genuine, Distance: 1.0000
# Pair 171: Type: Genuine, Distance: 0.2767
# Pair 172: Type: Genuine, Distance: 0.6503
# Pair 173: Type: Genuine, Distance: 0.6096
# Pair 174: Type: Genuine, Distance: 0.8200
# Pair 175: Type: Genuine, Distance: 0.4814
# Pair 176: Type: Genuine, Distance: 0.3774
# Pair 177: Type: Genuine, Distance: 0.5896
# Pair 178: Type: Genuine, Distance: 0.4471
# Pair 179: Type: Genuine, Distance: 0.6956
# Pair 180: Type: Genuine, Distance: 0.7294
# Pair 181: Type: Genuine, Distance: 0.4904
# Pair 182: Type: Genuine, Distance: 0.0050
# Pair 183: Type: Genuine, Distance: 0.4421
# Pair 184: Type: Genuine, Distance: 0.5958
# Pair 185: Type: Genuine, Distance: 0.0117
# Pair 186: Type: Genuine, Distance: 0.5415
# Pair 187: Type: Genuine, Distance: 0.5303
# Pair 188: Type: Genuine, Distance: 0.0160
# Pair 189: Type: Genuine, Distance: 0.4544
# Pair 190: Type: Genuine, Distance: 0.6854
# Pair 191: Type: Genuine, Distance: 0.7335
# Pair 192: Type: Genuine, Distance: 0.7148
# Pair 193: Type: Genuine, Distance: 0.3494
# Pair 194: Type: Genuine, Distance: 0.7914
# Pair 195: Type: Genuine, Distance: 0.8649
# Pair 196: Type: Genuine, Distance: 0.5302
# Pair 197: Type: Genuine, Distance: 0.9999
# Pair 198: Type: Genuine, Distance: 0.4184
# Pair 199: Type: Genuine, Distance: 0.7924
# Pair 200: Type: Genuine, Distance: 0.4242
# Pair 201: Type: Genuine, Distance: 0.8528
# Pair 202: Type: Genuine, Distance: 0.3424
# Pair 203: Type: Genuine, Distance: 0.9828
# Pair 204: Type: Genuine, Distance: 0.9512
# Pair 205: Type: Genuine, Distance: 0.2362
# Pair 206: Type: Genuine, Distance: 0.6067
# Pair 207: Type: Genuine, Distance: 0.2090
# Pair 208: Type: Genuine, Distance: 0.9973
# Pair 209: Type: Genuine, Distance: 0.7070
# Pair 210: Type: Genuine, Distance: 0.6179
# Pair 211: Type: Genuine, Distance: 0.7020
# Pair 212: Type: Genuine, Distance: 0.5592
# Pair 213: Type: Genuine, Distance: 0.0024
# Pair 214: Type: Genuine, Distance: 0.8523
# Pair 215: Type: Genuine, Distance: 0.5321
# Pair 216: Type: Genuine, Distance: 0.1302
# Pair 217: Type: Genuine, Distance: 0.6505
# Pair 218: Type: Genuine, Distance: 0.4504
# Pair 219: Type: Genuine, Distance: 0.3475
# Pair 220: Type: Genuine, Distance: 0.5112
# Pair 221: Type: Genuine, Distance: 0.5242
# Pair 222: Type: Genuine, Distance: 0.2013
# Pair 223: Type: Genuine, Distance: 0.3369
# Pair 224: Type: Genuine, Distance: 0.6045
# Pair 225: Type: Genuine, Distance: 0.9999
# Pair 226: Type: Genuine, Distance: 0.9998
# Pair 227: Type: Genuine, Distance: 0.6135
# Pair 228: Type: Genuine, Distance: 0.8580
# Pair 229: Type: Genuine, Distance: 0.5243
# Pair 230: Type: Genuine, Distance: 0.8860
# Pair 231: Type: Genuine, Distance: 0.0853
# Pair 232: Type: Genuine, Distance: 0.9997
# Pair 233: Type: Genuine, Distance: 0.3601
# Pair 234: Type: Genuine, Distance: 0.9983
# Pair 235: Type: Genuine, Distance: 0.2829
# Pair 236: Type: Genuine, Distance: 1.0000
# Pair 237: Type: Genuine, Distance: 0.3011
# Pair 238: Type: Genuine, Distance: 0.1453
# Pair 239: Type: Genuine, Distance: 0.6496
# Pair 240: Type: Genuine, Distance: 0.9939
# Pair 241: Type: Genuine, Distance: 0.5965
# Pair 242: Type: Genuine, Distance: 0.0014
# Pair 243: Type: Genuine, Distance: 0.4908
# Pair 244: Type: Genuine, Distance: 0.0781
# Pair 245: Type: Genuine, Distance: 0.0155
# Pair 246: Type: Genuine, Distance: 0.0037
# Pair 247: Type: Genuine, Distance: 0.0093
# Pair 248: Type: Genuine, Distance: 0.1811
# Pair 249: Type: Genuine, Distance: 0.6416
# Pair 250: Type: Genuine, Distance: 0.1973
# Pair 251: Type: Genuine, Distance: 0.4104
# Pair 252: Type: Genuine, Distance: 0.3769
# Pair 253: Type: Genuine, Distance: 0.7013
# Pair 254: Type: Genuine, Distance: 0.8723
# Pair 255: Type: Genuine, Distance: 0.0192
# Pair 256: Type: Genuine, Distance: 0.0048
# Pair 257: Type: Genuine, Distance: 0.9998
# Pair 258: Type: Genuine, Distance: 0.9434
# Pair 259: Type: Genuine, Distance: 0.8541
# Pair 260: Type: Genuine, Distance: 0.8240
# Pair 261: Type: Genuine, Distance: 0.2386
# Pair 262: Type: Genuine, Distance: 0.1047
# Pair 263: Type: Genuine, Distance: 0.1391
# Pair 264: Type: Genuine, Distance: 0.8178
# Pair 265: Type: Genuine, Distance: 0.8872
# Pair 266: Type: Genuine, Distance: 0.3874
# Pair 267: Type: Genuine, Distance: 0.2562
# Pair 268: Type: Genuine, Distance: 0.9996
# Pair 269: Type: Genuine, Distance: 0.0390
# Pair 270: Type: Genuine, Distance: 0.9322
# Pair 271: Type: Genuine, Distance: 0.9930
# Pair 272: Type: Genuine, Distance: 0.9667
# Pair 273: Type: Genuine, Distance: 0.6560
# Pair 274: Type: Genuine, Distance: 0.5246
# Pair 275: Type: Genuine, Distance: 0.2225
# Pair 276: Type: Genuine, Distance: 0.8667
# Pair 277: Type: Genuine, Distance: 0.2203
# Pair 278: Type: Genuine, Distance: 0.3139
# Pair 279: Type: Genuine, Distance: 0.8066
# Pair 280: Type: Genuine, Distance: 0.5472
# Pair 281: Type: Genuine, Distance: 0.8555
# Pair 282: Type: Genuine, Distance: 0.2805
# Pair 283: Type: Genuine, Distance: 0.4147
# Pair 284: Type: Genuine, Distance: 0.5663
# Pair 285: Type: Genuine, Distance: 0.4702
# Pair 286: Type: Genuine, Distance: 0.2923
# Pair 287: Type: Genuine, Distance: 0.2213
# Pair 288: Type: Genuine, Distance: 0.2503
# Pair 289: Type: Genuine, Distance: 0.5940
# Pair 290: Type: Genuine, Distance: 0.9866
# Pair 291: Type: Genuine, Distance: 0.7300
# Pair 292: Type: Genuine, Distance: 0.2549
# Pair 293: Type: Genuine, Distance: 0.5856
# Pair 294: Type: Genuine, Distance: 0.7219
# Pair 295: Type: Genuine, Distance: 0.3286
# Pair 296: Type: Genuine, Distance: 0.7306
# Pair 297: Type: Genuine, Distance: 0.7943
# Pair 298: Type: Genuine, Distance: 0.5361
# Pair 299: Type: Genuine, Distance: 0.8949
# Pair 300: Type: Genuine, Distance: 0.9979
# Pair 301: Type: Genuine, Distance: 0.4024
# Pair 302: Type: Genuine, Distance: 0.2328
# Pair 303: Type: Genuine, Distance: 0.6963
# Pair 304: Type: Genuine, Distance: 0.5469
# Pair 305: Type: Genuine, Distance: 0.0046
# Pair 306: Type: Genuine, Distance: 0.4914
# Pair 307: Type: Genuine, Distance: 0.2499
# Pair 308: Type: Genuine, Distance: 0.3774
# Pair 309: Type: Genuine, Distance: 0.6209
# Pair 310: Type: Genuine, Distance: 0.0019
# Pair 311: Type: Genuine, Distance: 0.0552
# Pair 312: Type: Genuine, Distance: 0.4104
# Pair 313: Type: Genuine, Distance: 0.8397
# Pair 314: Type: Genuine, Distance: 0.3851
# Pair 315: Type: Genuine, Distance: 0.3951
# Pair 316: Type: Genuine, Distance: 0.5201
# Pair 317: Type: Genuine, Distance: 0.3548
# Pair 318: Type: Genuine, Distance: 0.0046
# Pair 319: Type: Genuine, Distance: 0.6500
# Pair 320: Type: Genuine, Distance: 0.3451
# Pair 321: Type: Genuine, Distance: 0.2903
# Pair 322: Type: Genuine, Distance: 0.2761
# Pair 323: Type: Genuine, Distance: 0.6805
# Pair 324: Type: Genuine, Distance: 0.9978
# Pair 325: Type: Genuine, Distance: 0.0992
# Pair 326: Type: Genuine, Distance: 0.5890
# Pair 327: Type: Genuine, Distance: 0.9830
# Pair 328: Type: Genuine, Distance: 0.9996
# Pair 329: Type: Genuine, Distance: 0.7362
# Pair 330: Type: Genuine, Distance: 0.9995
# Pair 331: Type: Genuine, Distance: 0.9788
# Pair 332: Type: Genuine, Distance: 0.3179
# Pair 333: Type: Genuine, Distance: 0.9997
# Pair 334: Type: Genuine, Distance: 0.4631
# Pair 335: Type: Genuine, Distance: 0.6909
# Pair 336: Type: Genuine, Distance: 0.6935
# Pair 337: Type: Genuine, Distance: 0.5562
# Pair 338: Type: Genuine, Distance: 0.0953
# Pair 339: Type: Genuine, Distance: 0.7191
# Pair 340: Type: Genuine, Distance: 0.0034
# Pair 341: Type: Genuine, Distance: 0.2758
# Pair 342: Type: Genuine, Distance: 0.6459
# Pair 343: Type: Genuine, Distance: 0.0168
# Pair 344: Type: Genuine, Distance: 0.3600
# Pair 345: Type: Genuine, Distance: 0.2332
# Pair 346: Type: Genuine, Distance: 0.2658
# Pair 347: Type: Genuine, Distance: 0.0118
# Pair 348: Type: Genuine, Distance: 0.5720
# Pair 349: Type: Genuine, Distance: 0.2109
# Pair 350: Type: Genuine, Distance: 0.1876
# Pair 351: Type: Genuine, Distance: 0.0207
# Pair 352: Type: Genuine, Distance: 0.1320
# Pair 353: Type: Genuine, Distance: 0.8434
# Pair 354: Type: Genuine, Distance: 0.1616
# Pair 355: Type: Genuine, Distance: 0.6710
# Pair 356: Type: Genuine, Distance: 0.9900
# Pair 357: Type: Genuine, Distance: 0.6414
# Pair 358: Type: Genuine, Distance: 0.7480
# Pair 359: Type: Genuine, Distance: 0.9951
# Pair 360: Type: Genuine, Distance: 0.6281
# Pair 361: Type: Genuine, Distance: 0.9049
# Pair 362: Type: Genuine, Distance: 0.8263
# Pair 363: Type: Genuine, Distance: 0.7452
# Pair 364: Type: Genuine, Distance: 0.9823
# Pair 365: Type: Genuine, Distance: 0.2554
# Pair 366: Type: Genuine, Distance: 0.3319
# Pair 367: Type: Genuine, Distance: 0.9999
# Pair 368: Type: Genuine, Distance: 0.9998
# Pair 369: Type: Genuine, Distance: 0.4119
# Pair 370: Type: Genuine, Distance: 0.0244
# Pair 371: Type: Genuine, Distance: 0.1995
# Pair 372: Type: Genuine, Distance: 0.3172
# Pair 373: Type: Genuine, Distance: 0.5219
# Pair 374: Type: Genuine, Distance: 0.0082
# Pair 375: Type: Genuine, Distance: 0.1764
# Pair 376: Type: Genuine, Distance: 0.0828
# Pair 377: Type: Genuine, Distance: 0.6438
# Pair 378: Type: Genuine, Distance: 0.3198
# Pair 379: Type: Genuine, Distance: 0.0963
# Pair 380: Type: Genuine, Distance: 0.4393
# Pair 381: Type: Genuine, Distance: 0.8510
# Pair 382: Type: Genuine, Distance: 0.7070
# Pair 383: Type: Genuine, Distance: 0.0949
# Pair 384: Type: Genuine, Distance: 0.0054
# Pair 385: Type: Genuine, Distance: 0.8798
# Pair 386: Type: Genuine, Distance: 0.4949
# Pair 387: Type: Genuine, Distance: 0.7988
# Pair 388: Type: Genuine, Distance: 0.0600
# Pair 389: Type: Genuine, Distance: 0.7096
# Pair 390: Type: Genuine, Distance: 0.3403
# Pair 391: Type: Genuine, Distance: 0.9996
# Pair 392: Type: Genuine, Distance: 0.9189
# Pair 393: Type: Genuine, Distance: 0.7999
# Pair 394: Type: Genuine, Distance: 0.6368
# Pair 395: Type: Genuine, Distance: 0.8390
# Pair 396: Type: Genuine, Distance: 0.0913
# Pair 397: Type: Genuine, Distance: 0.4870
# Pair 398: Type: Genuine, Distance: 0.1650
# Pair 399: Type: Genuine, Distance: 0.2966
# Pair 400: Type: Genuine, Distance: 0.8774
# Pair 401: Type: Genuine, Distance: 0.2702
# Pair 402: Type: Genuine, Distance: 0.1030
# Pair 403: Type: Genuine, Distance: 0.8487
# Pair 404: Type: Genuine, Distance: 0.6782
# Pair 405: Type: Genuine, Distance: 0.6989
# Pair 406: Type: Genuine, Distance: 0.2282
# Pair 407: Type: Genuine, Distance: 0.3549
# Pair 408: Type: Genuine, Distance: 0.8940
# Pair 409: Type: Genuine, Distance: 0.6352
# Pair 410: Type: Genuine, Distance: 0.0018
# Pair 411: Type: Genuine, Distance: 0.1707
# Pair 412: Type: Genuine, Distance: 0.4272
# Pair 413: Type: Genuine, Distance: 0.0427
# Pair 414: Type: Genuine, Distance: 0.0340
# Pair 415: Type: Genuine, Distance: 0.4264
# Pair 416: Type: Genuine, Distance: 0.0234
# Pair 417: Type: Genuine, Distance: 0.4001
# Pair 418: Type: Genuine, Distance: 0.4793
# Pair 419: Type: Genuine, Distance: 0.3289
# Pair 420: Type: Genuine, Distance: 0.2123
# Pair 421: Type: Genuine, Distance: 0.9318
# Pair 422: Type: Genuine, Distance: 0.0858
# Pair 423: Type: Genuine, Distance: 0.9999
# Pair 424: Type: Genuine, Distance: 0.2155
# Pair 425: Type: Genuine, Distance: 0.2567
# Pair 426: Type: Genuine, Distance: 0.2228
# Pair 427: Type: Genuine, Distance: 0.5106
# Pair 428: Type: Genuine, Distance: 0.4297
# Pair 429: Type: Genuine, Distance: 0.5104
# Pair 430: Type: Genuine, Distance: 0.6139
# Pair 431: Type: Genuine, Distance: 0.2582
# Pair 432: Type: Genuine, Distance: 0.0557
# Pair 433: Type: Genuine, Distance: 0.0340
# Pair 434: Type: Genuine, Distance: 0.2822
# Pair 435: Type: Genuine, Distance: 0.2042
# Pair 436: Type: Genuine, Distance: 0.3270
# Pair 437: Type: Genuine, Distance: 0.4935
# Pair 438: Type: Genuine, Distance: 0.3456
# Pair 439: Type: Genuine, Distance: 0.7073
# Pair 440: Type: Genuine, Distance: 0.8399
# Pair 441: Type: Genuine, Distance: 0.5346
# Pair 442: Type: Genuine, Distance: 0.4737
# Pair 443: Type: Genuine, Distance: 0.2376
# Pair 444: Type: Genuine, Distance: 0.6629
# Pair 445: Type: Genuine, Distance: 0.3394
# Pair 446: Type: Genuine, Distance: 0.3308
# Pair 447: Type: Genuine, Distance: 0.6880
# Pair 448: Type: Genuine, Distance: 0.2554
# Pair 449: Type: Genuine, Distance: 0.4142
# Pair 450: Type: Genuine, Distance: 1.0000
# Pair 451: Type: Genuine, Distance: 0.9986
# Pair 452: Type: Genuine, Distance: 0.0993
# Pair 453: Type: Genuine, Distance: 0.8662
# Pair 454: Type: Genuine, Distance: 0.9990
# Pair 455: Type: Genuine, Distance: 0.9533
# Pair 456: Type: Genuine, Distance: 0.4910
# Pair 457: Type: Genuine, Distance: 0.9820
# Pair 458: Type: Genuine, Distance: 0.1359
# Pair 459: Type: Genuine, Distance: 1.0000
# Pair 460: Type: Genuine, Distance: 0.9982
# Pair 461: Type: Genuine, Distance: 0.3146
# Pair 462: Type: Genuine, Distance: 0.3684
# Pair 463: Type: Genuine, Distance: 0.5066
# Pair 464: Type: Genuine, Distance: 0.9998
# Pair 465: Type: Genuine, Distance: 0.3809
# Pair 466: Type: Genuine, Distance: 0.2648
# Pair 467: Type: Genuine, Distance: 0.0173
# Pair 468: Type: Genuine, Distance: 0.7154
# Pair 469: Type: Genuine, Distance: 0.6782
# Pair 470: Type: Genuine, Distance: 0.0200
# Pair 471: Type: Genuine, Distance: 0.1521
# Pair 472: Type: Genuine, Distance: 0.4514
# Pair 473: Type: Genuine, Distance: 0.3644
# Pair 474: Type: Genuine, Distance: 0.2080
# Pair 475: Type: Genuine, Distance: 0.7339
# Pair 476: Type: Genuine, Distance: 0.2043
# Pair 477: Type: Genuine, Distance: 0.0290
# Pair 478: Type: Genuine, Distance: 0.0510
# Pair 479: Type: Genuine, Distance: 0.0318
# Pair 480: Type: Genuine, Distance: 0.1696
# Pair 481: Type: Genuine, Distance: 0.3238
# Pair 482: Type: Genuine, Distance: 0.7171
# Pair 483: Type: Genuine, Distance: 0.2009
# Pair 484: Type: Genuine, Distance: 0.9998
# Pair 485: Type: Genuine, Distance: 0.8118
# Pair 486: Type: Genuine, Distance: 0.2192
# Pair 487: Type: Genuine, Distance: 0.1091
# Pair 488: Type: Genuine, Distance: 0.5975
# Pair 489: Type: Genuine, Distance: 0.9713
# Pair 490: Type: Genuine, Distance: 0.6178
# Pair 491: Type: Genuine, Distance: 1.0000
# Pair 492: Type: Genuine, Distance: 0.9972
# Pair 493: Type: Genuine, Distance: 0.3407
# Pair 494: Type: Genuine, Distance: 0.6836
# Pair 495: Type: Genuine, Distance: 0.5328
# Pair 496: Type: Genuine, Distance: 0.0989
# Pair 497: Type: Genuine, Distance: 0.5693
# Pair 498: Type: Genuine, Distance: 0.4612
# Pair 499: Type: Genuine, Distance: 0.2188
# Pair 500: Type: Genuine, Distance: 0.3369
# Pair 501: Type: Genuine, Distance: 0.2346
# Pair 502: Type: Genuine, Distance: 0.3871
# Pair 503: Type: Genuine, Distance: 0.4936
# Pair 504: Type: Genuine, Distance: 0.3121
# Pair 505: Type: Genuine, Distance: 0.4004
# Pair 506: Type: Genuine, Distance: 0.4780
# Pair 507: Type: Genuine, Distance: 0.6660
# Pair 508: Type: Genuine, Distance: 0.6293
# Pair 509: Type: Genuine, Distance: 0.4054
# Pair 510: Type: Genuine, Distance: 0.6490
# Pair 511: Type: Genuine, Distance: 0.3589
# Pair 512: Type: Genuine, Distance: 0.4930
# Pair 513: Type: Forged, Distance: 0.8235
# Pair 514: Type: Forged, Distance: 0.6514
# Pair 515: Type: Forged, Distance: 0.6801
# Pair 516: Type: Forged, Distance: 1.0000
# Pair 517: Type: Forged, Distance: 0.8614
# Pair 518: Type: Forged, Distance: 0.9560
# Pair 519: Type: Forged, Distance: 0.9999
# Pair 520: Type: Forged, Distance: 0.2342
# Pair 521: Type: Forged, Distance: 0.0823
# Pair 522: Type: Forged, Distance: 1.0000
# Pair 523: Type: Forged, Distance: 0.6164
# Pair 524: Type: Forged, Distance: 0.9390
# Pair 525: Type: Forged, Distance: 0.2464
# Pair 526: Type: Forged, Distance: 0.5434
# Pair 527: Type: Forged, Distance: 0.4949
# Pair 528: Type: Forged, Distance: 0.8454
# Pair 529: Type: Forged, Distance: 0.6264
# Pair 530: Type: Forged, Distance: 0.2485
# Pair 531: Type: Forged, Distance: 0.6462
# Pair 532: Type: Forged, Distance: 0.1900
# Pair 533: Type: Forged, Distance: 0.3812
# Pair 534: Type: Forged, Distance: 0.4604
# Pair 535: Type: Forged, Distance: 0.6631
# Pair 536: Type: Forged, Distance: 0.5983
# Pair 537: Type: Forged, Distance: 0.2579
# Pair 538: Type: Forged, Distance: 0.8363
# Pair 539: Type: Forged, Distance: 0.0127
# Pair 540: Type: Forged, Distance: 0.4948
# Pair 541: Type: Forged, Distance: 0.6393
# Pair 542: Type: Forged, Distance: 0.0055
# Pair 543: Type: Forged, Distance: 0.4433
# Pair 544: Type: Forged, Distance: 0.0031
# Pair 545: Type: Forged, Distance: 0.9999
# Pair 546: Type: Forged, Distance: 0.6870
# Pair 547: Type: Forged, Distance: 0.9534
# Pair 548: Type: Forged, Distance: 0.2787
# Pair 549: Type: Forged, Distance: 0.2729
# Pair 550: Type: Forged, Distance: 1.0000
# Pair 551: Type: Forged, Distance: 0.0991
# Pair 552: Type: Forged, Distance: 0.6220
# Pair 553: Type: Forged, Distance: 0.5621
# Pair 554: Type: Forged, Distance: 0.3474
# Pair 555: Type: Forged, Distance: 0.1064
# Pair 556: Type: Forged, Distance: 0.9939
# Pair 557: Type: Forged, Distance: 0.4621
# Pair 558: Type: Forged, Distance: 0.5670
# Pair 559: Type: Forged, Distance: 0.1914
# Pair 560: Type: Forged, Distance: 0.3600
# Pair 561: Type: Forged, Distance: 0.3853
# Pair 562: Type: Forged, Distance: 0.1544
# Pair 563: Type: Forged, Distance: 0.4508
# Pair 564: Type: Forged, Distance: 0.3675
# Pair 565: Type: Forged, Distance: 0.5544
# Pair 566: Type: Forged, Distance: 0.1267
# Pair 567: Type: Forged, Distance: 0.6645
# Pair 568: Type: Forged, Distance: 0.1439
# Pair 569: Type: Forged, Distance: 0.3506
# Pair 570: Type: Forged, Distance: 0.6242
# Pair 571: Type: Forged, Distance: 0.2282
# Pair 572: Type: Forged, Distance: 0.3293
# Pair 573: Type: Forged, Distance: 0.4903
# Pair 574: Type: Forged, Distance: 0.4322
# Pair 575: Type: Forged, Distance: 0.4834
# Pair 576: Type: Forged, Distance: 0.0043
# Pair 577: Type: Forged, Distance: 0.5182
# Pair 578: Type: Forged, Distance: 0.8184
# Pair 579: Type: Forged, Distance: 0.9346
# Pair 580: Type: Forged, Distance: 0.2096
# Pair 581: Type: Forged, Distance: 0.4949
# Pair 582: Type: Forged, Distance: 0.9858
# Pair 583: Type: Forged, Distance: 0.7511
# Pair 584: Type: Forged, Distance: 0.5738
# Pair 585: Type: Forged, Distance: 0.9936
# Pair 586: Type: Forged, Distance: 0.6902
# Pair 587: Type: Forged, Distance: 0.9972
# Pair 588: Type: Forged, Distance: 0.8026
# Pair 589: Type: Forged, Distance: 0.6896
# Pair 590: Type: Forged, Distance: 0.9311
# Pair 591: Type: Forged, Distance: 0.6976
# Pair 592: Type: Forged, Distance: 0.2400
# Pair 593: Type: Forged, Distance: 0.9064
# Pair 594: Type: Forged, Distance: 0.5945
# Pair 595: Type: Forged, Distance: 0.0260
# Pair 596: Type: Forged, Distance: 0.4812
# Pair 597: Type: Forged, Distance: 0.0272
# Pair 598: Type: Forged, Distance: 0.7020
# Pair 599: Type: Forged, Distance: 0.3355
# Pair 600: Type: Forged, Distance: 0.0190
# Pair 601: Type: Forged, Distance: 0.4746
# Pair 602: Type: Forged, Distance: 0.1853
# Pair 603: Type: Forged, Distance: 0.1182
# Pair 604: Type: Forged, Distance: 0.0390
# Pair 605: Type: Forged, Distance: 0.6806
# Pair 606: Type: Forged, Distance: 0.2254
# Pair 607: Type: Forged, Distance: 0.1714
# Pair 608: Type: Forged, Distance: 0.0859
# Pair 609: Type: Forged, Distance: 0.4812
# Pair 610: Type: Forged, Distance: 0.0721
# Pair 611: Type: Forged, Distance: 0.3327
# Pair 612: Type: Forged, Distance: 0.8367
# Pair 613: Type: Forged, Distance: 0.1135
# Pair 614: Type: Forged, Distance: 0.6408
# Pair 615: Type: Forged, Distance: 0.4417
# Pair 616: Type: Forged, Distance: 0.6399
# Pair 617: Type: Forged, Distance: 0.0839
# Pair 618: Type: Forged, Distance: 0.9973
# Pair 619: Type: Forged, Distance: 0.2292
# Pair 620: Type: Forged, Distance: 0.3855
# Pair 621: Type: Forged, Distance: 0.4885
# Pair 622: Type: Forged, Distance: 0.1716
# Pair 623: Type: Forged, Distance: 0.4949
# Pair 624: Type: Forged, Distance: 0.5342
# Pair 625: Type: Forged, Distance: 0.8680
# Pair 626: Type: Forged, Distance: 0.3571
# Pair 627: Type: Forged, Distance: 0.5657
# Pair 628: Type: Forged, Distance: 0.0020
# Pair 629: Type: Forged, Distance: 0.1965
# Pair 630: Type: Forged, Distance: 0.0030
# Pair 631: Type: Forged, Distance: 0.2243
# Pair 632: Type: Forged, Distance: 0.1039
# Pair 633: Type: Forged, Distance: 0.3986
# Pair 634: Type: Forged, Distance: 0.2924
# Pair 635: Type: Forged, Distance: 0.0096
# Pair 636: Type: Forged, Distance: 0.1881
# Pair 637: Type: Forged, Distance: 0.1011
# Pair 638: Type: Forged, Distance: 0.5238
# Pair 639: Type: Forged, Distance: 0.5033
# Pair 640: Type: Forged, Distance: 0.8077
# Pair 641: Type: Forged, Distance: 0.3280
# Pair 642: Type: Forged, Distance: 0.9949
# Pair 643: Type: Forged, Distance: 0.9832
# Pair 644: Type: Forged, Distance: 0.9993
# Pair 645: Type: Forged, Distance: 0.7474
# Pair 646: Type: Forged, Distance: 0.6385
# Pair 647: Type: Forged, Distance: 0.7927
# Pair 648: Type: Forged, Distance: 0.5831
# Pair 649: Type: Forged, Distance: 0.3041
# Pair 650: Type: Forged, Distance: 0.8295
# Pair 651: Type: Forged, Distance: 0.9916
# Pair 652: Type: Forged, Distance: 0.9337
# Pair 653: Type: Forged, Distance: 0.9142
# Pair 654: Type: Forged, Distance: 0.3665
# Pair 655: Type: Forged, Distance: 0.4863
# Pair 656: Type: Forged, Distance: 0.9981
# Pair 657: Type: Forged, Distance: 0.1876
# Pair 658: Type: Forged, Distance: 0.2262
# Pair 659: Type: Forged, Distance: 0.3804
# Pair 660: Type: Forged, Distance: 0.4701
# Pair 661: Type: Forged, Distance: 0.3138
# Pair 662: Type: Forged, Distance: 0.4299
# Pair 663: Type: Forged, Distance: 0.1125
# Pair 664: Type: Forged, Distance: 0.4236
# Pair 665: Type: Forged, Distance: 0.3502
# Pair 666: Type: Forged, Distance: 0.0010
# Pair 667: Type: Forged, Distance: 0.3314
# Pair 668: Type: Forged, Distance: 0.4711
# Pair 669: Type: Forged, Distance: 0.6072
# Pair 670: Type: Forged, Distance: 0.3785
# Pair 671: Type: Forged, Distance: 0.2525
# Pair 672: Type: Forged, Distance: 0.5329
# Pair 673: Type: Forged, Distance: 0.7842
# Pair 674: Type: Forged, Distance: 0.4396
# Pair 675: Type: Forged, Distance: 0.9999
# Pair 676: Type: Forged, Distance: 0.4729
# Pair 677: Type: Forged, Distance: 0.9998
# Pair 678: Type: Forged, Distance: 0.9995
# Pair 679: Type: Forged, Distance: 0.1237
# Pair 680: Type: Forged, Distance: 0.8382
# Pair 681: Type: Forged, Distance: 0.2268
# Pair 682: Type: Forged, Distance: 0.9463
# Pair 683: Type: Forged, Distance: 0.9844
# Pair 684: Type: Forged, Distance: 0.2286
# Pair 685: Type: Forged, Distance: 0.5977
# Pair 686: Type: Forged, Distance: 0.6752
# Pair 687: Type: Forged, Distance: 0.1527
# Pair 688: Type: Forged, Distance: 0.8450
# Pair 689: Type: Forged, Distance: 0.3685
# Pair 690: Type: Forged, Distance: 0.5966
# Pair 691: Type: Forged, Distance: 0.1552
# Pair 692: Type: Forged, Distance: 0.3951
# Pair 693: Type: Forged, Distance: 0.4947
# Pair 694: Type: Forged, Distance: 0.5896
# Pair 695: Type: Forged, Distance: 0.2510
# Pair 696: Type: Forged, Distance: 0.3507
# Pair 697: Type: Forged, Distance: 0.4124
# Pair 698: Type: Forged, Distance: 0.6297
# Pair 699: Type: Forged, Distance: 0.0067
# Pair 700: Type: Forged, Distance: 0.0814
# Pair 701: Type: Forged, Distance: 0.0150
# Pair 702: Type: Forged, Distance: 0.7350
# Pair 703: Type: Forged, Distance: 0.7700
# Pair 704: Type: Forged, Distance: 0.3506
# Pair 705: Type: Forged, Distance: 0.9067
# Pair 706: Type: Forged, Distance: 0.9998
# Pair 707: Type: Forged, Distance: 0.5580
# Pair 708: Type: Forged, Distance: 0.9998
# Pair 709: Type: Forged, Distance: 0.8603
# Pair 710: Type: Forged, Distance: 0.9359
# Pair 711: Type: Forged, Distance: 0.7802
# Pair 712: Type: Forged, Distance: 0.1692
# Pair 713: Type: Forged, Distance: 0.6798
# Pair 714: Type: Forged, Distance: 0.4119
# Pair 715: Type: Forged, Distance: 0.5451
# Pair 716: Type: Forged, Distance: 0.1575
# Pair 717: Type: Forged, Distance: 1.0000
# Pair 718: Type: Forged, Distance: 0.2219
# Pair 719: Type: Forged, Distance: 0.4368
# Pair 720: Type: Forged, Distance: 0.4500
# Pair 721: Type: Forged, Distance: 0.5097
# Pair 722: Type: Forged, Distance: 0.4761
# Pair 723: Type: Forged, Distance: 0.3745
# Pair 724: Type: Forged, Distance: 0.2644
# Pair 725: Type: Forged, Distance: 0.2661
# Pair 726: Type: Forged, Distance: 0.5494
# Pair 727: Type: Forged, Distance: 0.3823
# Pair 728: Type: Forged, Distance: 0.3275
# Pair 729: Type: Forged, Distance: 0.2585
# Pair 730: Type: Forged, Distance: 0.3463
# Pair 731: Type: Forged, Distance: 0.8159
# Pair 732: Type: Forged, Distance: 0.3651
# Pair 733: Type: Forged, Distance: 0.0050
# Pair 734: Type: Forged, Distance: 0.0242
# Pair 735: Type: Forged, Distance: 0.4355
# Pair 736: Type: Forged, Distance: 0.6596
# Pair 737: Type: Forged, Distance: 0.5222
# Pair 738: Type: Forged, Distance: 0.1956
# Pair 739: Type: Forged, Distance: 0.3130
# Pair 740: Type: Forged, Distance: 0.6782
# Pair 741: Type: Forged, Distance: 0.1606
# Pair 742: Type: Forged, Distance: 0.9999
# Pair 743: Type: Forged, Distance: 0.2772
# Pair 744: Type: Forged, Distance: 0.4269
# Pair 745: Type: Forged, Distance: 0.0763
# Pair 746: Type: Forged, Distance: 0.5354
# Pair 747: Type: Forged, Distance: 0.4141
# Pair 748: Type: Forged, Distance: 0.3044
# Pair 749: Type: Forged, Distance: 0.4344
# Pair 750: Type: Forged, Distance: 0.5791
# Pair 751: Type: Forged, Distance: 0.9256
# Pair 752: Type: Forged, Distance: 0.1424
# Pair 753: Type: Forged, Distance: 0.3893
# Pair 754: Type: Forged, Distance: 0.1570
# Pair 755: Type: Forged, Distance: 0.8004
# Pair 756: Type: Forged, Distance: 0.3456
# Pair 757: Type: Forged, Distance: 0.3208
# Pair 758: Type: Forged, Distance: 0.0470
# Pair 759: Type: Forged, Distance: 0.2432
# Pair 760: Type: Forged, Distance: 0.4031
# Pair 761: Type: Forged, Distance: 0.5434
# Pair 762: Type: Forged, Distance: 0.8386
# Pair 763: Type: Forged, Distance: 0.4770
# Pair 764: Type: Forged, Distance: 0.1062
# Pair 765: Type: Forged, Distance: 0.3618
# Pair 766: Type: Forged, Distance: 0.8510
# Pair 767: Type: Forged, Distance: 0.3901
# Pair 768: Type: Forged, Distance: 0.1942
# Pair 769: Type: Forged, Distance: 0.6686
# Pair 770: Type: Forged, Distance: 0.5814
# Pair 771: Type: Forged, Distance: 0.1093
# Pair 772: Type: Forged, Distance: 0.5122
# Pair 773: Type: Forged, Distance: 0.4409
# Pair 774: Type: Forged, Distance: 0.9996
# Pair 775: Type: Forged, Distance: 0.9893
# Pair 776: Type: Forged, Distance: 0.3445
# Pair 777: Type: Forged, Distance: 0.1650
# Pair 778: Type: Forged, Distance: 0.9758
# Pair 779: Type: Forged, Distance: 0.9981
# Pair 780: Type: Forged, Distance: 0.3841
# Pair 781: Type: Forged, Distance: 0.4949
# Pair 782: Type: Forged, Distance: 0.9910
# Pair 783: Type: Forged, Distance: 0.9503
# Pair 784: Type: Forged, Distance: 0.4912
# Pair 785: Type: Forged, Distance: 0.1493
# Pair 786: Type: Forged, Distance: 0.0898
# Pair 787: Type: Forged, Distance: 0.4356
# Pair 788: Type: Forged, Distance: 0.6559
# Pair 789: Type: Forged, Distance: 0.4432
# Pair 790: Type: Forged, Distance: 0.0234
# Pair 791: Type: Forged, Distance: 0.3385
# Pair 792: Type: Forged, Distance: 0.0811
# Pair 793: Type: Forged, Distance: 0.5561
# Pair 794: Type: Forged, Distance: 0.2537
# Pair 795: Type: Forged, Distance: 0.5309
# Pair 796: Type: Forged, Distance: 0.0060
# Pair 797: Type: Forged, Distance: 0.2332
# Pair 798: Type: Forged, Distance: 0.1372
# Pair 799: Type: Forged, Distance: 0.0261
# Pair 800: Type: Forged, Distance: 0.1493
# Pair 801: Type: Forged, Distance: 0.9145
# Pair 802: Type: Forged, Distance: 0.6875
# Pair 803: Type: Forged, Distance: 0.9997
# Pair 804: Type: Forged, Distance: 0.8540
# Pair 805: Type: Forged, Distance: 0.7484
# Pair 806: Type: Forged, Distance: 0.8984
# Pair 807: Type: Forged, Distance: 0.4610
# Pair 808: Type: Forged, Distance: 0.3012
# Pair 809: Type: Forged, Distance: 0.7123
# Pair 810: Type: Forged, Distance: 0.6489
# Pair 811: Type: Forged, Distance: 0.8963
# Pair 812: Type: Forged, Distance: 0.9994
# Pair 813: Type: Forged, Distance: 0.2588
# Pair 814: Type: Forged, Distance: 0.4138
# Pair 815: Type: Forged, Distance: 0.4420
# Pair 816: Type: Forged, Distance: 0.5245
# Pair 817: Type: Forged, Distance: 0.6692
# Pair 818: Type: Forged, Distance: 0.4904
# Pair 819: Type: Forged, Distance: 0.2587
# Pair 820: Type: Forged, Distance: 0.1822
# Pair 821: Type: Forged, Distance: 0.3950
# Pair 822: Type: Forged, Distance: 0.5244
# Pair 823: Type: Forged, Distance: 0.6668
# Pair 824: Type: Forged, Distance: 0.0228
# Pair 825: Type: Forged, Distance: 0.0509
# Pair 826: Type: Forged, Distance: 0.1067
# Pair 827: Type: Forged, Distance: 0.6059
# Pair 828: Type: Forged, Distance: 0.5472
# Pair 829: Type: Forged, Distance: 0.8801
# Pair 830: Type: Forged, Distance: 0.1965
# Pair 831: Type: Forged, Distance: 0.2760
# Pair 832: Type: Forged, Distance: 0.2004
# Pair 833: Type: Forged, Distance: 0.4514
# Pair 834: Type: Forged, Distance: 0.9999
# Pair 835: Type: Forged, Distance: 0.9997
# Pair 836: Type: Forged, Distance: 0.4434
# Pair 837: Type: Forged, Distance: 0.7889
# Pair 838: Type: Forged, Distance: 0.3636
# Pair 839: Type: Forged, Distance: 0.9823
# Pair 840: Type: Forged, Distance: 0.4303
# Pair 841: Type: Forged, Distance: 0.0813
# Pair 842: Type: Forged, Distance: 0.9329
# Pair 843: Type: Forged, Distance: 0.9862
# Pair 844: Type: Forged, Distance: 0.7506
# Pair 845: Type: Forged, Distance: 0.2158
# Pair 846: Type: Forged, Distance: 0.2189
# Pair 847: Type: Forged, Distance: 0.9770
# Pair 848: Type: Forged, Distance: 0.0293
# Pair 849: Type: Forged, Distance: 0.9519
# Pair 850: Type: Forged, Distance: 0.4460
# Pair 851: Type: Forged, Distance: 0.3741
# Pair 852: Type: Forged, Distance: 0.3119
# Pair 853: Type: Forged, Distance: 0.1956
# Pair 854: Type: Forged, Distance: 0.0028
# Pair 855: Type: Forged, Distance: 0.1903
# Pair 856: Type: Forged, Distance: 0.4895
# Pair 857: Type: Forged, Distance: 0.3283
# Pair 858: Type: Forged, Distance: 0.7111
# Pair 859: Type: Forged, Distance: 0.5382
# Pair 860: Type: Forged, Distance: 0.8671
# Pair 861: Type: Forged, Distance: 0.2933
# Pair 862: Type: Forged, Distance: 0.3818
# Pair 863: Type: Forged, Distance: 0.7377
# Pair 864: Type: Forged, Distance: 0.2537
# Pair 865: Type: Forged, Distance: 0.5516
# Pair 866: Type: Forged, Distance: 0.4387
# Pair 867: Type: Forged, Distance: 0.7135
# Pair 868: Type: Forged, Distance: 0.6754
# Pair 869: Type: Forged, Distance: 0.9395
# Pair 870: Type: Forged, Distance: 0.9347
# Pair 871: Type: Forged, Distance: 0.6612
# Pair 872: Type: Forged, Distance: 0.5372
# Pair 873: Type: Forged, Distance: 0.0490
# Pair 874: Type: Forged, Distance: 0.9998
# Pair 875: Type: Forged, Distance: 0.3478
# Pair 876: Type: Forged, Distance: 0.0937
# Pair 877: Type: Forged, Distance: 0.6296
# Pair 878: Type: Forged, Distance: 0.4500
# Pair 879: Type: Forged, Distance: 0.2128
# Pair 880: Type: Forged, Distance: 0.0841
# Pair 881: Type: Forged, Distance: 0.2525
# Pair 882: Type: Forged, Distance: 0.2376
# Pair 883: Type: Forged, Distance: 0.3688
# Pair 884: Type: Forged, Distance: 0.4476
# Pair 885: Type: Forged, Distance: 0.8316
# Pair 886: Type: Forged, Distance: 0.6828
# Pair 887: Type: Forged, Distance: 0.0962
# Pair 888: Type: Forged, Distance: 0.5652
# Pair 889: Type: Forged, Distance: 0.3863
# Pair 890: Type: Forged, Distance: 0.8114
# Pair 891: Type: Forged, Distance: 0.6560
# Pair 892: Type: Forged, Distance: 0.5837
# Pair 893: Type: Forged, Distance: 0.5218
# Pair 894: Type: Forged, Distance: 0.0343
# Pair 895: Type: Forged, Distance: 0.2080
# Pair 896: Type: Forged, Distance: 0.4757
# Pair 897: Type: Forged, Distance: 0.9994
# Pair 898: Type: Forged, Distance: 0.3094
# Pair 899: Type: Forged, Distance: 0.9990
# Pair 900: Type: Forged, Distance: 0.1721
# Pair 901: Type: Forged, Distance: 0.7725
# Pair 902: Type: Forged, Distance: 0.1977
# Pair 903: Type: Forged, Distance: 0.6784
# Pair 904: Type: Forged, Distance: 0.9032
# Pair 905: Type: Forged, Distance: 0.9854
# Pair 906: Type: Forged, Distance: 0.7563
# Pair 907: Type: Forged, Distance: 0.6462
# Pair 908: Type: Forged, Distance: 0.9994
# Pair 909: Type: Forged, Distance: 0.9798
# Pair 910: Type: Forged, Distance: 0.1524
# Pair 911: Type: Forged, Distance: 0.3567
# Pair 912: Type: Forged, Distance: 0.5994
# Pair 913: Type: Forged, Distance: 0.6393
# Pair 914: Type: Forged, Distance: 0.8199
# Pair 915: Type: Forged, Distance: 0.1618
# Pair 916: Type: Forged, Distance: 0.1829
# Pair 917: Type: Forged, Distance: 0.0037
# Pair 918: Type: Forged, Distance: 0.2107
# Pair 919: Type: Forged, Distance: 0.3926
# Pair 920: Type: Forged, Distance: 0.2009
# Pair 921: Type: Forged, Distance: 0.6540
# Pair 922: Type: Forged, Distance: 0.7762
# Pair 923: Type: Forged, Distance: 0.5966
# Pair 924: Type: Forged, Distance: 0.2701
# Pair 925: Type: Forged, Distance: 0.7970
# Pair 926: Type: Forged, Distance: 0.2821
# Pair 927: Type: Forged, Distance: 0.0173
# Pair 928: Type: Forged, Distance: 0.0171
# Pair 929: Type: Forged, Distance: 0.3273
# Pair 930: Type: Forged, Distance: 0.5516
# Pair 931: Type: Forged, Distance: 0.9293
# Pair 932: Type: Forged, Distance: 0.9840
# Pair 933: Type: Forged, Distance: 0.5132
# Pair 934: Type: Forged, Distance: 0.8424
# Pair 935: Type: Forged, Distance: 0.6716
# Pair 936: Type: Forged, Distance: 1.0000
# Pair 937: Type: Forged, Distance: 0.9119
# Pair 938: Type: Forged, Distance: 0.7497
# Pair 939: Type: Forged, Distance: 0.5534
# Pair 940: Type: Forged, Distance: 0.7699
# Pair 941: Type: Forged, Distance: 0.7707
# Pair 942: Type: Forged, Distance: 0.3988
# Pair 943: Type: Forged, Distance: 0.6687
# Pair 944: Type: Forged, Distance: 0.7442
# Pair 945: Type: Forged, Distance: 0.4168
# Pair 946: Type: Forged, Distance: 0.6560
# Pair 947: Type: Forged, Distance: 0.6880
# Pair 948: Type: Forged, Distance: 0.0698
# Pair 949: Type: Forged, Distance: 0.1374
# Pair 950: Type: Forged, Distance: 0.2739
# Pair 951: Type: Forged, Distance: 0.2875
# Pair 952: Type: Forged, Distance: 0.3172
# Pair 953: Type: Forged, Distance: 0.4904
# Pair 954: Type: Forged, Distance: 0.5218
# Pair 955: Type: Forged, Distance: 0.5391
# Pair 956: Type: Forged, Distance: 0.3924
# Pair 957: Type: Forged, Distance: 0.2383
# Pair 958: Type: Forged, Distance: 0.2682
# Pair 959: Type: Forged, Distance: 0.2594
# Pair 960: Type: Forged, Distance: 0.4960
# Pair 961: Type: Forged, Distance: 0.3763
# Pair 962: Type: Forged, Distance: 0.8259
# Pair 963: Type: Forged, Distance: 0.8892
# Pair 964: Type: Forged, Distance: 0.2960
# Pair 965: Type: Forged, Distance: 0.1613
# Pair 966: Type: Forged, Distance: 0.9983
# Pair 967: Type: Forged, Distance: 0.3131
# Pair 968: Type: Forged, Distance: 0.6138
# Pair 969: Type: Forged, Distance: 0.4479
# Pair 970: Type: Forged, Distance: 0.8690
# Pair 971: Type: Forged, Distance: 1.0000
# Pair 972: Type: Forged, Distance: 0.8955
# Pair 973: Type: Forged, Distance: 0.4572
# Pair 974: Type: Forged, Distance: 0.9996
# Pair 975: Type: Forged, Distance: 0.7927
# Pair 976: Type: Forged, Distance: 0.2080
# Pair 977: Type: Forged, Distance: 0.2225
# Pair 978: Type: Forged, Distance: 0.8469
# Pair 979: Type: Forged, Distance: 0.7807
# Pair 980: Type: Forged, Distance: 0.2760
# Pair 981: Type: Forged, Distance: 0.5125
# Pair 982: Type: Forged, Distance: 0.7058
# Pair 983: Type: Forged, Distance: 0.1883
# Pair 984: Type: Forged, Distance: 0.6775
# Pair 985: Type: Forged, Distance: 0.6869
# Pair 986: Type: Forged, Distance: 0.6120
# Pair 987: Type: Forged, Distance: 0.4834
# Pair 988: Type: Forged, Distance: 0.4039
# Pair 989: Type: Forged, Distance: 0.4433
# Pair 990: Type: Forged, Distance: 0.1896
# Pair 991: Type: Forged, Distance: 0.3819
# Pair 992: Type: Forged, Distance: 0.4036
# Pair 993: Type: Forged, Distance: 0.8247
# Pair 994: Type: Forged, Distance: 0.9933
# Pair 995: Type: Forged, Distance: 0.5687
# Pair 996: Type: Forged, Distance: 0.4878
# Pair 997: Type: Forged, Distance: 0.9994
# Pair 998: Type: Forged, Distance: 0.5188
# Pair 999: Type: Forged, Distance: 0.9998
# Pair 1000: Type: Forged, Distance: 0.9994
# Pair 1001: Type: Forged, Distance: 0.4570
# Pair 1002: Type: Forged, Distance: 0.9969
# Pair 1003: Type: Forged, Distance: 0.4456
# Pair 1004: Type: Forged, Distance: 0.9722
# Pair 1005: Type: Forged, Distance: 0.1374
# Pair 1006: Type: Forged, Distance: 0.6109
# Pair 1007: Type: Forged, Distance: 0.6560
# Pair 1008: Type: Forged, Distance: 0.9997
# Pair 1009: Type: Forged, Distance: 0.6687
# Pair 1010: Type: Forged, Distance: 0.3045
# Pair 1011: Type: Forged, Distance: 0.5106
# Pair 1012: Type: Forged, Distance: 0.2308
# Pair 1013: Type: Forged, Distance: 0.6241
# Pair 1014: Type: Forged, Distance: 0.6417
# Pair 1015: Type: Forged, Distance: 0.8458
# Pair 1016: Type: Forged, Distance: 0.0151
# Pair 1017: Type: Forged, Distance: 0.3941
# Pair 1018: Type: Forged, Distance: 0.2008
# Pair 1019: Type: Forged, Distance: 0.0098
# Pair 1020: Type: Forged, Distance: 0.7277
# Pair 1021: Type: Forged, Distance: 0.8111
# Pair 1022: Type: Forged, Distance: 0.0056
# Pair 1023: Type: Forged, Distance: 0.1481
# Pair 1024: Type: Forged, Distance: 0.6987

# %%
# Print paths of all images in the test set
for orig_group, forg_group in zip(orig_test, forg_test):
    print("Originals:")
    for img_path in orig_group:
        print(img_path)
    print("Forged:")
    for img_path in forg_group:
        print(img_path)
# Out:
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-G-17.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-26.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/112/H-S-112-F-30.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_18.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_20.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_21.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_3.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_6.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_16.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_23.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_4.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_17.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/original_18_15.png
# Forged:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_2.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_9.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_15.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_17.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_11.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_14.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_3.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_16.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_4.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/18/forgeries_18_24.png
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-G-08.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/144/H-S-144-F-04.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-G-09.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-30.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/31/B-S-31-F-07.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-G-14.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-26.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-29.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/17/H-S-017-F-12.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-G-02.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-30.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-29.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-27.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/62/B-S-62-F-16.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-G-09.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-30.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/15/H-S-15-F-17.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-G-08.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/101/H-S-101-F-28.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-G-14.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/56/H-S-56-F-18.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-G-07.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-27.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-26.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/58/H-S-58-F-06.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-G-19.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-30.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-26.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/70/B-S-70-F-25.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-G-06.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-29.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-26.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/34/B-S-34-F-08.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-G-02.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-29.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/151/H-S-151-F-17.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-G-03.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-27.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/1/B-S-1-F-12.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-G-08.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/69/H-S-69-F-19.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-G-17.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-30.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-27.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/84/B-S-84-F-21.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-G-07.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-27.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-26.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/27/B-S-27-F-05.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-G-13.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-29.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-26.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-30.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/68/H-S-68-F-05.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-G-24.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/127/H-S-127-F-04.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-G-10.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-26.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-30.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/17/B-S-17-F-05.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_9.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_3.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_14.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_15.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_6.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_23.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_17.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_24.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_18.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/original_32_10.png
# Forged:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_15.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_9.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_3.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_22.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_13.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_21.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_14.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_17.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_6.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/32/forgeries_32_12.png
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-G-22.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-27.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/6/H-S-6-F-21.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-G-04.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/43/B-S-43-F-25.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_23.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_12.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_21.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_2.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_22.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_13.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_7.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_14.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_17.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/original_27_18.png
# Forged:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_4.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_11.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_8.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_23.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_7.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_3.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_13.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_9.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_6.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/27/forgeries_27_17.png
# Originals:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_20.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_24.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_1.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_3.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_22.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_21.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_10.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_15.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_2.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/original_47_18.png
# Forged:
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_16.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_14.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_8.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_21.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_1.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_7.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_19.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_6.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_9.png
# /content/drive/MyDrive/Multilingual dataset/CEDAR/47/forgeries_47_13.png
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-G-16.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-28.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-30.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/56/B-S-56-F-24.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-G-05.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/52/B-S-52-F-25.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-G-19.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-27.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-29.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/37/B-S-37-F-18.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-G-02.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-06.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-29.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-03.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Bengali/94/B-S-94-F-28.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-13.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-G-20.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-30.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/94/H-S-94-F-20.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-01.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-14.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-G-23.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-27.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-16.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-23.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-22.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-08.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-05.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/79/H-S-79-F-30.tif
# Originals:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-20.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-24.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-21.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-10.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-17.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-07.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-11.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-124-G-06.tif
# Forged:
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-19.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-04.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-09.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-25.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-18.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-12.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-26.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-02.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-15.tif
# /content/drive/MyDrive/Multilingual dataset/BHSig260-Hindi/123/H-S-123-F-24.tif
